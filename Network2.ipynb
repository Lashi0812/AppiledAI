# %% [markdown]
# <a href="https://colab.research.google.com/github/Lashi0812/AppiledAI/blob/master/Network2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### Libraries
# Standard library
import json
import random
import sys
import pickle
import gzip

# Third-party libraries
import numpy as np


#### Define the quadratic and cross-entropy cost functions

class QuadraticCost(object):

    @staticmethod
    def fn(a, y):
        """Return the cost associated with an output ``a`` and desired output
        ``y``.

        """
        return 0.5 * np.linalg.norm(a - y) ** 2

    @staticmethod
    def delta(z, a, y):
        """Return the error delta from the output layer."""
        return (a - y) * sigmoid_prime(z)


class CrossEntropyCost(object):

    @staticmethod
    def fn(a, y):
        """Return the cost associated with an output ``a`` and desired output
        ``y``.  Note that np.nan_to_num is used to ensure numerical
        stability.  In particular, if both ``a`` and ``y`` have a 1.0
        in the same slot, then the expression (1-y)*np.log(1-a)
        returns nan.  The np.nan_to_num ensures that that is converted
        to the correct value (0.0).

        """
        return np.sum(np.nan_to_num(-y * np.log(a) - (1 - y) * np.log(1 - a)))

    @staticmethod
    def delta(z, a, y):
        """Return the error delta from the output layer.  Note that the
        parameter ``z`` is not used by the method.  It is included in
        the method's parameters in order to make the interface
        consistent with the delta method for other cost classes.

        """
        return (a - y)


#### Main Network class
class Network(object):

    def __init__(self, sizes, cost=CrossEntropyCost):
        """The list ``sizes`` contains the number of neurons in the respective
        layers of the network.  For example, if the list was [2, 3, 1]
        then it would be a three-layer network, with the first layer
        containing 2 neurons, the second layer 3 neurons, and the
        third layer 1 neuron.  The biases and weights for the network
        are initialized randomly, using
        ``self.default_weight_initializer`` (see docstring for that
        method).

        """
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.default_weight_initializer()
        self.cost = cost

    def default_weight_initializer(self):
        """Initialize each weight using a Gaussian distribution with mean 0
        and standard deviation 1 over the square root of the number of
        weights connecting to the same neuron.  Initialize the biases
        using a Gaussian distribution with mean 0 and standard
        deviation 1.

        Note that the first layer is assumed to be an input layer, and
        by convention we won't set any biases for those neurons, since
        biases are only ever used in computing the outputs from later
        layers.

        """
        self.biases = [np.random.randn(y, 1) for y in self.sizes[1:]]
        self.weights = [np.random.randn(y, x) / np.sqrt(x)
                        for x, y in zip(self.sizes[:-1], self.sizes[1:])]

    def large_weight_initializer(self):
        """Initialize the weights using a Gaussian distribution with mean 0
        and standard deviation 1.  Initialize the biases using a
        Gaussian distribution with mean 0 and standard deviation 1.

        Note that the first layer is assumed to be an input layer, and
        by convention we won't set any biases for those neurons, since
        biases are only ever used in computing the outputs from later
        layers.

        This weight and bias initializer uses the same approach as in
        Chapter 1, and is included for purposes of comparison.  It
        will usually be better to use the default weight initializer
        instead.

        """
        self.biases = [np.random.randn(y, 1) for y in self.sizes[1:]]
        self.weights = [np.random.randn(y, x)
                        for x, y in zip(self.sizes[:-1], self.sizes[1:])]

    def feedforward(self, a):
        """Return the output of the network if ``a`` is input."""
        for b, w in zip(self.biases, self.weights):
            a = sigmoid(np.dot(w, a) + b)
        return a

    def SGD(self, training_data, epochs, mini_batch_size, eta,
            lmbda=0.0,
            evaluation_data=None,
            monitor_evaluation_cost=False,
            monitor_evaluation_accuracy=False,
            monitor_training_cost=False,
            monitor_training_accuracy=False):
        """Train the neural network using mini-batch stochastic gradient
        descent.  The ``training_data`` is a list of tuples ``(x, y)``
        representing the training inputs and the desired outputs.  The
        other non-optional parameters are self-explanatory, as is the
        regularization parameter ``lmbda``.  The method also accepts
        ``evaluation_data``, usually either the validation or test
        data.  We can monitor the cost and accuracy on either the
        evaluation data or the training data, by setting the
        appropriate flags.  The method returns a tuple containing four
        lists: the (per-epoch) costs on the evaluation data, the
        accuracies on the evaluation data, the costs on the training
        data, and the accuracies on the training data.  All values are
        evaluated at the end of each training epoch.  So, for example,
        if we train for 30 epochs, then the first element of the tuple
        will be a 30-element list containing the cost on the
        evaluation data at the end of each epoch. Note that the lists
        are empty if the corresponding flag is not set.

        """
        if evaluation_data: n_data = len(evaluation_data)
        n = len(training_data)
        evaluation_cost, evaluation_accuracy = [], []
        training_cost, training_accuracy = [], []
        for j in range(epochs):
            random.shuffle(training_data)
            mini_batches = [
                training_data[k:k + mini_batch_size]
                for k in range(0, n, mini_batch_size)]
            for mini_batch in mini_batches:
                self.update_mini_batch(
                    mini_batch, eta, lmbda, len(training_data))
            print("Epoch %s training complete" % j)
            if monitor_training_cost:
                cost = self.total_cost(training_data, lmbda)
                training_cost.append(cost)
                print("Cost on training data: {}".format(cost))
            if monitor_training_accuracy:
                accuracy = self.accuracy(training_data, convert=True)
                training_accuracy.append(accuracy)
                print("Accuracy on training data: {} / {}".format(
                    accuracy, n))
            if monitor_evaluation_cost:
                cost = self.total_cost(evaluation_data, lmbda, convert=True)
                evaluation_cost.append(cost)
                print("Cost on evaluation data: {}".format(cost))
            if monitor_evaluation_accuracy:
                accuracy = self.accuracy(evaluation_data)
                evaluation_accuracy.append(accuracy)
                print("Accuracy on evaluation data: {} / {}".format(
                    self.accuracy(evaluation_data), n_data))
            print()
        return evaluation_cost, evaluation_accuracy, training_cost, training_accuracy

    def update_mini_batch(self, mini_batch, eta, lmbda, n):
        """Update the network's weights and biases by applying gradient
        descent using backpropagation to a single mini batch.  The
        ``mini_batch`` is a list of tuples ``(x, y)``, ``eta`` is the
        learning rate, ``lmbda`` is the regularization parameter, and
        ``n`` is the total size of the training data set.

        """
        nabla_b = [np.zeros(b.shape) for b in self.biases]
        nabla_w = [np.zeros(w.shape) for w in self.weights]
        for x, y in mini_batch:
            delta_nabla_b, delta_nabla_w = self.backprop(x, y)
            nabla_b = [nb + dnb for nb, dnb in zip(nabla_b, delta_nabla_b)]
            nabla_w = [nw + dnw for nw, dnw in zip(nabla_w, delta_nabla_w)]
        self.weights = [(1 - eta * (lmbda / n)) * w - (eta / len(mini_batch)) * nw
                        for w, nw in zip(self.weights, nabla_w)]
        self.biases = [b - (eta / len(mini_batch)) * nb
                       for b, nb in zip(self.biases, nabla_b)]

    def backprop(self, x, y):
        """Return a tuple ``(nabla_b, nabla_w)`` representing the
        gradient for the cost function C_x.  ``nabla_b`` and
        ``nabla_w`` are layer-by-layer lists of numpy arrays, similar
        to ``self.biases`` and ``self.weights``."""
        nabla_b = [np.zeros(b.shape) for b in self.biases]
        nabla_w = [np.zeros(w.shape) for w in self.weights]
        # feedforward
        activation = x
        activations = [x]  # list to store all the activations, layer by layer
        zs = []  # list to store all the z vectors, layer by layer
        for b, w in zip(self.biases, self.weights):
            z = np.dot(w, activation) + b
            zs.append(z)
            activation = sigmoid(z)
            activations.append(activation)
        # backward pass
        delta = (self.cost).delta(zs[-1], activations[-1], y)
        nabla_b[-1] = delta
        nabla_w[-1] = np.dot(delta, activations[-2].transpose())
        # Note that the variable l in the loop below is used a little
        # differently to the notation in Chapter 2 of the book.  Here,
        # l = 1 means the last layer of neurons, l = 2 is the
        # second-last layer, and so on.  It's a renumbering of the
        # scheme in the book, used here to take advantage of the fact
        # that Python can use negative indices in lists.
        for l in range(2, self.num_layers):
            z = zs[-l]
            sp = sigmoid_prime(z)
            delta = np.dot(self.weights[-l + 1].transpose(), delta) * sp
            nabla_b[-l] = delta
            nabla_w[-l] = np.dot(delta, activations[-l - 1].transpose())
        return (nabla_b, nabla_w)

    def accuracy(self, data, convert=False):
        """Return the number of inputs in ``data`` for which the neural
        network outputs the correct result. The neural network's
        output is assumed to be the index of whichever neuron in the
        final layer has the highest activation.

        The flag ``convert`` should be set to False if the data set is
        validation or test data (the usual case), and to True if the
        data set is the training data. The need for this flag arises
        due to differences in the way the results ``y`` are
        represented in the different data sets.  In particular, it
        flags whether we need to convert between the different
        representations.  It may seem strange to use different
        representations for the different data sets.  Why not use the
        same representation for all three data sets?  It's done for
        efficiency reasons -- the program usually evaluates the cost
        on the training data and the accuracy on other data sets.
        These are different types of computations, and using different
        representations speeds things up.  More details on the
        representations can be found in
        mnist_loader.load_data_wrapper.

        """
        if convert:
            results = [(np.argmax(self.feedforward(x)), np.argmax(y))
                       for (x, y) in data]
        else:
            results = [(np.argmax(self.feedforward(x)), y)
                       for (x, y) in data]
        return sum(int(x == y) for (x, y) in results)

    def total_cost(self, data, lmbda, convert=False):
        """Return the total cost for the data set ``data``.  The flag
        ``convert`` should be set to False if the data set is the
        training data (the usual case), and to True if the data set is
        the validation or test data.  See comments on the similar (but
        reversed) convention for the ``accuracy`` method, above.
        """
        cost = 0.0
        for x, y in data:
            a = self.feedforward(x)
            if convert: y = vectorized_result(y)
            cost += self.cost.fn(a, y) / len(data)
        cost += 0.5 * (lmbda / len(data)) * sum(
            np.linalg.norm(w) ** 2 for w in self.weights)
        return cost

    def save(self, filename):
        """Save the neural network to the file ``filename``."""
        data = {"sizes": self.sizes,
                "weights": [w.tolist() for w in self.weights],
                "biases": [b.tolist() for b in self.biases],
                "cost": str(self.cost.__name__)}
        f = open(filename, "w")
        json.dump(data, f)
        f.close()


#### Loading a Network
def load(filename):
    """Load a neural network from the file ``filename``.  Returns an
    instance of Network.

    """
    f = open(filename, "r")
    data = json.load(f)
    f.close()
    cost = getattr(sys.modules[__name__], data["cost"])
    net = Network(data["sizes"], cost=cost)
    net.weights = [np.array(w) for w in data["weights"]]
    net.biases = [np.array(b) for b in data["biases"]]
    return net


#### Miscellaneous functions
def vectorized_result(j):
    """Return a 10-dimensional unit vector with a 1.0 in the j'th position
    and zeroes elsewhere.  This is used to convert a digit (0...9)
    into a corresponding desired output from the neural network.

    """
    e = np.zeros((10, 1))
    e[j] = 1.0
    return e


def sigmoid(z):
    """The sigmoid function."""
    return 1.0 / (1.0 + np.exp(-z))


def sigmoid_prime(z):
    """Derivative of the sigmoid function."""
    return sigmoid(z) * (1 - sigmoid(z))

# %%
def load_data():
    """Return the MNIST data as a tuple containing the training data,
    the validation data, and the test data.

    The ``training_data`` is returned as a tuple with two entries.
    The first entry contains the actual training images.  This is a
    numpy ndarray with 50,000 entries.  Each entry is, in turn, a
    numpy ndarray with 784 values, representing the 28 * 28 = 784
    pixels in a single MNIST image.

    The second entry in the ``training_data`` tuple is a numpy ndarray
    containing 50,000 entries.  Those entries are just the digit
    values (0...9) for the corresponding images contained in the first
    entry of the tuple.

    The ``validation_data`` and ``test_data`` are similar, except
    each contains only 10,000 images.

    This is a nice data format, but for use in neural networks it's
    helpful to modify the format of the ``training_data`` a little.
    That's done in the wrapper function ``load_data_wrapper()``, see
    below.
    """
    f = gzip.open('/content/mnist.pkl.gz', 'rb')
    training_data, validation_data, test_data = pickle.load(f, encoding="latin1")
    f.close()
    return (training_data, validation_data, test_data)


def load_data_wrapper():
    """Return a tuple containing ``(training_data, validation_data,
    test_data)``. Based on ``load_data``, but the format is more
    convenient for use in our implementation of neural networks.

    In particular, ``training_data`` is a list containing 50,000
    2-tuples ``(x, y)``.  ``x`` is a 784-dimensional numpy.ndarray
    containing the input image.  ``y`` is a 10-dimensional
    numpy.ndarray representing the unit vector corresponding to the
    correct digit for ``x``.

    ``validation_data`` and ``test_data`` are lists containing 10,000
    2-tuples ``(x, y)``.  In each case, ``x`` is a 784-dimensional
    numpy.ndarry containing the input image, and ``y`` is the
    corresponding classification, i.e., the digit values (integers)
    corresponding to ``x``.

    Obviously, this means we're using slightly different formats for
    the training data and the validation / test data.  These formats
    turn out to be the most convenient for use in our neural network
    code."""
    tr_d, va_d, te_d = load_data()
    training_inputs = [np.reshape(x, (784, 1)) for x in tr_d[0]]
    training_results = [vectorized_result(y) for y in tr_d[1]]
    training_data = list(zip(training_inputs, training_results))
    validation_inputs = [np.reshape(x, (784, 1)) for x in va_d[0]]
    validation_data = list(zip(validation_inputs, va_d[1]))
    test_inputs = [np.reshape(x, (784, 1)) for x in te_d[0]]
    test_data = list(zip(test_inputs, te_d[1]))
    return (training_data, validation_data, test_data)


def vectorized_result(j):
    """Return a 10-dimensional unit vector with a 1.0 in the jth
    position and zeroes elsewhere.  This is used to convert a digit
    (0...9) into a corresponding desired output from the neural
    network."""
    e = np.zeros((10, 1))
    e[j] = 1.0
    return e

# %%
training_data, validation_Data, test_data = load_data_wrapper()
net = Network([784, 30, 10], cost=CrossEntropyCost)
net.large_weight_initializer()
evaluation_cost, evaluation_accuracy, training_cost, training_accuracy = net.SGD(
    training_data[:1000],
    400, 10, 0.5,
    evaluation_data=test_data,
    monitor_evaluation_accuracy=True,
    monitor_training_cost=True,
    monitor_evaluation_cost=True,
    monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 1.901582233472383
# Accuracy on training data: 637 / 1000
# Cost on evaluation data: 2.1660371500976354
# Accuracy on evaluation data: 5572 / 10000
#
# Epoch 1 training complete
# Cost on training data: 1.488364821771823
# Accuracy on training data: 733 / 1000
# Cost on evaluation data: 1.880468899220692
# Accuracy on evaluation data: 6204 / 10000
#
# Epoch 2 training complete
# Cost on training data: 1.1903993510534303
# Accuracy on training data: 803 / 1000
# Cost on evaluation data: 1.6513972923057143
# Accuracy on evaluation data: 6839 / 10000
#
# Epoch 3 training complete
# Cost on training data: 0.9485569264361755
# Accuracy on training data: 879 / 1000
# Cost on evaluation data: 1.4491697115374789
# Accuracy on evaluation data: 7396 / 10000
#
# Epoch 4 training complete
# Cost on training data: 0.8301760783428069
# Accuracy on training data: 894 / 1000
# Cost on evaluation data: 1.3835193272679065
# Accuracy on evaluation data: 7573 / 10000
#
# Epoch 5 training complete
# Cost on training data: 0.7528141141048552
# Accuracy on training data: 910 / 1000
# Cost on evaluation data: 1.3742276792205241
# Accuracy on evaluation data: 7593 / 10000
#
# Epoch 6 training complete
# Cost on training data: 0.666012284684238
# Accuracy on training data: 924 / 1000
# Cost on evaluation data: 1.3154607036506747
# Accuracy on evaluation data: 7747 / 10000
#
# Epoch 7 training complete
# Cost on training data: 0.5813278166752406
# Accuracy on training data: 934 / 1000
# Cost on evaluation data: 1.2639374482067516
# Accuracy on evaluation data: 7871 / 10000
#
# Epoch 8 training complete
# Cost on training data: 0.5254845385770216
# Accuracy on training data: 946 / 1000
# Cost on evaluation data: 1.2514216279810082
# Accuracy on evaluation data: 7883 / 10000
#
# Epoch 9 training complete
# Cost on training data: 0.4739968865024162
# Accuracy on training data: 952 / 1000
# Cost on evaluation data: 1.2108583981651262
# Accuracy on evaluation data: 8007 / 10000
#
# Epoch 10 training complete
# Cost on training data: 0.4377686362157906
# Accuracy on training data: 950 / 1000
# Cost on evaluation data: 1.2276939993509275
# Accuracy on evaluation data: 7960 / 10000
#
# Epoch 11 training complete
# Cost on training data: 0.39503593347810917
# Accuracy on training data: 959 / 1000
# Cost on evaluation data: 1.2181744632973848
# Accuracy on evaluation data: 8019 / 10000
#
# Epoch 12 training complete
# Cost on training data: 0.3674781535395914
# Accuracy on training data: 967 / 1000
# Cost on evaluation data: 1.185430042202123
# Accuracy on evaluation data: 8089 / 10000
#
# Epoch 13 training complete
# Cost on training data: 0.3292851825796335
# Accuracy on training data: 972 / 1000
# Cost on evaluation data: 1.1860689368253354
# Accuracy on evaluation data: 8080 / 10000
#
# Epoch 14 training complete
# Cost on training data: 0.30391929973567955
# Accuracy on training data: 969 / 1000
# Cost on evaluation data: 1.1853179571275887
# Accuracy on evaluation data: 8112 / 10000
#
# Epoch 15 training complete
# Cost on training data: 0.2838703962488887
# Accuracy on training data: 975 / 1000
# Cost on evaluation data: 1.185773814807132
# Accuracy on evaluation data: 8095 / 10000
#
# Epoch 16 training complete
# Cost on training data: 0.2659297056879107
# Accuracy on training data: 977 / 1000
# Cost on evaluation data: 1.2080066453788372
# Accuracy on evaluation data: 8079 / 10000
#
# Epoch 17 training complete
# Cost on training data: 0.2562033320429854
# Accuracy on training data: 975 / 1000
# Cost on evaluation data: 1.2171541738175202
# Accuracy on evaluation data: 8075 / 10000
#
# Epoch 18 training complete
# Cost on training data: 0.23076981900602395
# Accuracy on training data: 977 / 1000
# Cost on evaluation data: 1.1962983913688954
# Accuracy on evaluation data: 8112 / 10000
#
# Epoch 19 training complete
# Cost on training data: 0.2147221577206945
# Accuracy on training data: 980 / 1000
# Cost on evaluation data: 1.1977523855119707
# Accuracy on evaluation data: 8136 / 10000
#
# Epoch 20 training complete
# Cost on training data: 0.2105304300708955
# Accuracy on training data: 983 / 1000
# Cost on evaluation data: 1.2234370562906407
# Accuracy on evaluation data: 8092 / 10000
#
# Epoch 21 training complete
# Cost on training data: 0.1958761464537559
# Accuracy on training data: 983 / 1000
# Cost on evaluation data: 1.2113268597134819
# Accuracy on evaluation data: 8136 / 10000
#
# Epoch 22 training complete
# Cost on training data: 0.18716774353199686
# Accuracy on training data: 985 / 1000
# Cost on evaluation data: 1.2299075604407737
# Accuracy on evaluation data: 8109 / 10000
#
# Epoch 23 training complete
# Cost on training data: 0.17483306357780645
# Accuracy on training data: 985 / 1000
# Cost on evaluation data: 1.1959489065807831
# Accuracy on evaluation data: 8178 / 10000
#
# Epoch 24 training complete
# Cost on training data: 0.16150849395976916
# Accuracy on training data: 988 / 1000
# Cost on evaluation data: 1.1999391411309002
# Accuracy on evaluation data: 8166 / 10000
#
# Epoch 25 training complete
# Cost on training data: 0.15672693218741832
# Accuracy on training data: 988 / 1000
# Cost on evaluation data: 1.219716209628999
# Accuracy on evaluation data: 8158 / 10000
#
# Epoch 26 training complete
# Cost on training data: 0.15231779357895558
# Accuracy on training data: 991 / 1000
# Cost on evaluation data: 1.2328791795814686
# Accuracy on evaluation data: 8154 / 10000
#
# Epoch 27 training complete
# Cost on training data: 0.14371871724432275
# Accuracy on training data: 990 / 1000
# Cost on evaluation data: 1.2378209496251054
# Accuracy on evaluation data: 8152 / 10000
#
# Epoch 28 training complete
# Cost on training data: 0.13667247596219442
# Accuracy on training data: 988 / 1000
# Cost on evaluation data: 1.2214672564062188
# Accuracy on evaluation data: 8197 / 10000
#
# Epoch 29 training complete
# Cost on training data: 0.1312776805107218
# Accuracy on training data: 991 / 1000
# Cost on evaluation data: 1.2303022380859299
# Accuracy on evaluation data: 8196 / 10000
#
# Epoch 30 training complete
# Cost on training data: 0.12862761114083132
# Accuracy on training data: 991 / 1000
# Cost on evaluation data: 1.2424668975994932
# Accuracy on evaluation data: 8164 / 10000
#
# Epoch 31 training complete
# Cost on training data: 0.12049569488538908
# Accuracy on training data: 994 / 1000
# Cost on evaluation data: 1.236200094868832
# Accuracy on evaluation data: 8176 / 10000
#
# Epoch 32 training complete
# Cost on training data: 0.11492039960903364
# Accuracy on training data: 995 / 1000
# Cost on evaluation data: 1.2522529710051251
# Accuracy on evaluation data: 8175 / 10000
#
# Epoch 33 training complete
# Cost on training data: 0.10869108045412954
# Accuracy on training data: 995 / 1000
# Cost on evaluation data: 1.2421413542400244
# Accuracy on evaluation data: 8189 / 10000
#
# Epoch 34 training complete
# Cost on training data: 0.10374502921707768
# Accuracy on training data: 995 / 1000
# Cost on evaluation data: 1.257800990533141
# Accuracy on evaluation data: 8159 / 10000
#
# Epoch 35 training complete
# Cost on training data: 0.10003808913051007
# Accuracy on training data: 995 / 1000
# Cost on evaluation data: 1.2545348301738797
# Accuracy on evaluation data: 8196 / 10000
#
# Epoch 36 training complete
# Cost on training data: 0.09564030303642679
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 1.254891117565202
# Accuracy on evaluation data: 8196 / 10000
#
# Epoch 37 training complete
# Cost on training data: 0.09289325231198967
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.2613932110032642
# Accuracy on evaluation data: 8197 / 10000
#
# Epoch 38 training complete
# Cost on training data: 0.08920928455419877
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 1.2723298605854398
# Accuracy on evaluation data: 8180 / 10000
#
# Epoch 39 training complete
# Cost on training data: 0.08760991489436784
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.2675520578369472
# Accuracy on evaluation data: 8203 / 10000
#
# Epoch 40 training complete
# Cost on training data: 0.0831930458343689
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.2765504891098385
# Accuracy on evaluation data: 8187 / 10000
#
# Epoch 41 training complete
# Cost on training data: 0.08108456950037139
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 1.2791451726085168
# Accuracy on evaluation data: 8212 / 10000
#
# Epoch 42 training complete
# Cost on training data: 0.0791606492494087
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.2811894359999405
# Accuracy on evaluation data: 8207 / 10000
#
# Epoch 43 training complete
# Cost on training data: 0.07610237924663223
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 1.299237187586855
# Accuracy on evaluation data: 8186 / 10000
#
# Epoch 44 training complete
# Cost on training data: 0.07347353908247534
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 1.3018287909715969
# Accuracy on evaluation data: 8195 / 10000
#
# Epoch 45 training complete
# Cost on training data: 0.07249930634455043
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 1.2994251315023324
# Accuracy on evaluation data: 8186 / 10000
#
# Epoch 46 training complete
# Cost on training data: 0.06921933374754127
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 1.2987186878547985
# Accuracy on evaluation data: 8206 / 10000
#
# Epoch 47 training complete
# Cost on training data: 0.0677598243932776
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 1.302219614022031
# Accuracy on evaluation data: 8204 / 10000
#
# Epoch 48 training complete
# Cost on training data: 0.0657160585918275
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3031361216981727
# Accuracy on evaluation data: 8200 / 10000
#
# Epoch 49 training complete
# Cost on training data: 0.06410594520239062
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 1.309499765964378
# Accuracy on evaluation data: 8200 / 10000
#
# Epoch 50 training complete
# Cost on training data: 0.06233038948242404
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3068819380045773
# Accuracy on evaluation data: 8219 / 10000
#
# Epoch 51 training complete
# Cost on training data: 0.0603707418028822
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3167057374780433
# Accuracy on evaluation data: 8208 / 10000
#
# Epoch 52 training complete
# Cost on training data: 0.05859086731917763
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.312338095257471
# Accuracy on evaluation data: 8206 / 10000
#
# Epoch 53 training complete
# Cost on training data: 0.057501135444298614
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3164015254687127
# Accuracy on evaluation data: 8209 / 10000
#
# Epoch 54 training complete
# Cost on training data: 0.055833918070549646
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3303879270638033
# Accuracy on evaluation data: 8188 / 10000
#
# Epoch 55 training complete
# Cost on training data: 0.05470459934800726
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3204881909669304
# Accuracy on evaluation data: 8204 / 10000
#
# Epoch 56 training complete
# Cost on training data: 0.053300678494594016
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3334766398697284
# Accuracy on evaluation data: 8202 / 10000
#
# Epoch 57 training complete
# Cost on training data: 0.05200443062379035
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.328240162959389
# Accuracy on evaluation data: 8228 / 10000
#
# Epoch 58 training complete
# Cost on training data: 0.05089058667768213
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3359498517725472
# Accuracy on evaluation data: 8218 / 10000
#
# Epoch 59 training complete
# Cost on training data: 0.04981476716036644
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3379057838659323
# Accuracy on evaluation data: 8209 / 10000
#
# Epoch 60 training complete
# Cost on training data: 0.048890514278306825
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3422433941232645
# Accuracy on evaluation data: 8205 / 10000
#
# Epoch 61 training complete
# Cost on training data: 0.047674143678207166
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3391646811868458
# Accuracy on evaluation data: 8228 / 10000
#
# Epoch 62 training complete
# Cost on training data: 0.04676427615419761
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3429069668274562
# Accuracy on evaluation data: 8214 / 10000
#
# Epoch 63 training complete
# Cost on training data: 0.04592606602142479
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3506004864119838
# Accuracy on evaluation data: 8224 / 10000
#
# Epoch 64 training complete
# Cost on training data: 0.045266437034268525
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3569259689931923
# Accuracy on evaluation data: 8220 / 10000
#
# Epoch 65 training complete
# Cost on training data: 0.044000285316750695
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3502679835843554
# Accuracy on evaluation data: 8229 / 10000
#
# Epoch 66 training complete
# Cost on training data: 0.04388012747886589
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3599585558435239
# Accuracy on evaluation data: 8213 / 10000
#
# Epoch 67 training complete
# Cost on training data: 0.042330177420982405
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3607825548055368
# Accuracy on evaluation data: 8227 / 10000
#
# Epoch 68 training complete
# Cost on training data: 0.04148396448463526
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3611770030356127
# Accuracy on evaluation data: 8229 / 10000
#
# Epoch 69 training complete
# Cost on training data: 0.04062028696426695
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3652943127743842
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 70 training complete
# Cost on training data: 0.03987699842278805
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3691959665786253
# Accuracy on evaluation data: 8214 / 10000
#
# Epoch 71 training complete
# Cost on training data: 0.03911394519165822
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.368061161281595
# Accuracy on evaluation data: 8229 / 10000
#
# Epoch 72 training complete
# Cost on training data: 0.038446872753503
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3745305558765029
# Accuracy on evaluation data: 8227 / 10000
#
# Epoch 73 training complete
# Cost on training data: 0.037687987184224725
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3759827638437605
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 74 training complete
# Cost on training data: 0.037228020812727323
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.373996222950872
# Accuracy on evaluation data: 8224 / 10000
#
# Epoch 75 training complete
# Cost on training data: 0.03648670632390162
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3749510615704674
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 76 training complete
# Cost on training data: 0.03611848401936871
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3831390662344178
# Accuracy on evaluation data: 8224 / 10000
#
# Epoch 77 training complete
# Cost on training data: 0.03541636969258712
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3863763630714534
# Accuracy on evaluation data: 8223 / 10000
#
# Epoch 78 training complete
# Cost on training data: 0.034692681263630315
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3861341195624797
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 79 training complete
# Cost on training data: 0.03413953369064241
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3832129091864445
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 80 training complete
# Cost on training data: 0.03368824804738221
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.395315669903746
# Accuracy on evaluation data: 8223 / 10000
#
# Epoch 81 training complete
# Cost on training data: 0.03305170368789369
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3911385753826957
# Accuracy on evaluation data: 8237 / 10000
#
# Epoch 82 training complete
# Cost on training data: 0.03250046972442348
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.3943343032282611
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 83 training complete
# Cost on training data: 0.03213280919910076
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.4007901862733785
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 84 training complete
# Cost on training data: 0.031602322206135576
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4027843647792297
# Accuracy on evaluation data: 8226 / 10000
#
# Epoch 85 training complete
# Cost on training data: 0.031192867582893805
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4041256193461469
# Accuracy on evaluation data: 8225 / 10000
#
# Epoch 86 training complete
# Cost on training data: 0.030822740501586756
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.4005640540866442
# Accuracy on evaluation data: 8253 / 10000
#
# Epoch 87 training complete
# Cost on training data: 0.030186714160897257
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4063119348564936
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 88 training complete
# Cost on training data: 0.029860427316729964
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.4069149560252687
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 89 training complete
# Cost on training data: 0.029343824341536855
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4100779469559521
# Accuracy on evaluation data: 8229 / 10000
#
# Epoch 90 training complete
# Cost on training data: 0.02889332505155149
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4111239753270013
# Accuracy on evaluation data: 8237 / 10000
#
# Epoch 91 training complete
# Cost on training data: 0.028470867551062384
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4163563745555805
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 92 training complete
# Cost on training data: 0.02803989227988709
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4147253628978185
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 93 training complete
# Cost on training data: 0.027720714912209333
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4205253525006951
# Accuracy on evaluation data: 8231 / 10000
#
# Epoch 94 training complete
# Cost on training data: 0.027253493071054537
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4200571917236375
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 95 training complete
# Cost on training data: 0.02700631205734442
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4253815839346105
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 96 training complete
# Cost on training data: 0.026549253907059405
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4228255688343268
# Accuracy on evaluation data: 8228 / 10000
#
# Epoch 97 training complete
# Cost on training data: 0.02621082656608157
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4247594310958767
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 98 training complete
# Cost on training data: 0.025804294110728584
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4280233124547383
# Accuracy on evaluation data: 8246 / 10000
#
# Epoch 99 training complete
# Cost on training data: 0.025432279463129922
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4306173639439668
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 100 training complete
# Cost on training data: 0.02506198284679124
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4320198377099187
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 101 training complete
# Cost on training data: 0.024787473208668902
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.434380811180078
# Accuracy on evaluation data: 8249 / 10000
#
# Epoch 102 training complete
# Cost on training data: 0.02448494694759513
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.432921200862067
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 103 training complete
# Cost on training data: 0.024093676982169337
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4378597723071176
# Accuracy on evaluation data: 8237 / 10000
#
# Epoch 104 training complete
# Cost on training data: 0.02381957948443705
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.441977402314243
# Accuracy on evaluation data: 8236 / 10000
#
# Epoch 105 training complete
# Cost on training data: 0.023773518559212614
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.444025103763102
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 106 training complete
# Cost on training data: 0.02319470085910654
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4427669373205667
# Accuracy on evaluation data: 8250 / 10000
#
# Epoch 107 training complete
# Cost on training data: 0.02289543436748475
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4444899622697067
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 108 training complete
# Cost on training data: 0.02266629734248753
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4441999561033443
# Accuracy on evaluation data: 8250 / 10000
#
# Epoch 109 training complete
# Cost on training data: 0.02235726535861057
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4497521175215682
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 110 training complete
# Cost on training data: 0.02206445687597496
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4514717072509078
# Accuracy on evaluation data: 8250 / 10000
#
# Epoch 111 training complete
# Cost on training data: 0.021818517621134466
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.455096542882526
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 112 training complete
# Cost on training data: 0.021569688116336992
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4525564617553888
# Accuracy on evaluation data: 8246 / 10000
#
# Epoch 113 training complete
# Cost on training data: 0.021309978748418154
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.454307899313636
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 114 training complete
# Cost on training data: 0.021050590814676515
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4584483821370113
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 115 training complete
# Cost on training data: 0.02081268543205926
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.460827931149403
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 116 training complete
# Cost on training data: 0.020592066818988185
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4628852808180715
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 117 training complete
# Cost on training data: 0.020330038576482575
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4655435587573449
# Accuracy on evaluation data: 8245 / 10000
#
# Epoch 118 training complete
# Cost on training data: 0.020088506791402328
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4651947175067008
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 119 training complete
# Cost on training data: 0.019889413605816697
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4681045742711818
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 120 training complete
# Cost on training data: 0.01966886573890742
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4695599575098315
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 121 training complete
# Cost on training data: 0.019490794344985404
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4707017872130455
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 122 training complete
# Cost on training data: 0.019235676702844748
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4727903063701282
# Accuracy on evaluation data: 8247 / 10000
#
# Epoch 123 training complete
# Cost on training data: 0.01903176006280798
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4745739885407823
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 124 training complete
# Cost on training data: 0.018810875887928482
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.476668125125679
# Accuracy on evaluation data: 8245 / 10000
#
# Epoch 125 training complete
# Cost on training data: 0.018649686908766717
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4772725888668
# Accuracy on evaluation data: 8247 / 10000
#
# Epoch 126 training complete
# Cost on training data: 0.018443632392820316
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4804972746012433
# Accuracy on evaluation data: 8246 / 10000
#
# Epoch 127 training complete
# Cost on training data: 0.01823360261919533
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.480480666154595
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 128 training complete
# Cost on training data: 0.018022901183598245
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4823403286111994
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 129 training complete
# Cost on training data: 0.01786671421610144
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4820385372486595
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 130 training complete
# Cost on training data: 0.017660598924575593
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4851502258228573
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 131 training complete
# Cost on training data: 0.017491179267071794
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4885806732321225
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 132 training complete
# Cost on training data: 0.01733105365594676
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4894763409547371
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 133 training complete
# Cost on training data: 0.017133651709991756
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4901978448646336
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 134 training complete
# Cost on training data: 0.0169709124964473
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4904484954487862
# Accuracy on evaluation data: 8245 / 10000
#
# Epoch 135 training complete
# Cost on training data: 0.016809731311822795
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4938234705028688
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 136 training complete
# Cost on training data: 0.016635928953214998
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4945540531718011
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 137 training complete
# Cost on training data: 0.016476130753271173
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4955811664198142
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 138 training complete
# Cost on training data: 0.01632904816256968
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4974143099688828
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 139 training complete
# Cost on training data: 0.016179171997529766
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.497898489180481
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 140 training complete
# Cost on training data: 0.016058804510004836
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.4985297189779294
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 141 training complete
# Cost on training data: 0.015881298844245773
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5025204525052256
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 142 training complete
# Cost on training data: 0.015728606304969247
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5041631172444414
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 143 training complete
# Cost on training data: 0.015583377981741614
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5058525212170741
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 144 training complete
# Cost on training data: 0.015441457913775013
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5059951520345327
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 145 training complete
# Cost on training data: 0.015304004898310778
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5080639543143177
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 146 training complete
# Cost on training data: 0.015174368308524
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5104949033292399
# Accuracy on evaluation data: 8237 / 10000
#
# Epoch 147 training complete
# Cost on training data: 0.015023951967229155
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.50878874172799
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 148 training complete
# Cost on training data: 0.014899187417378812
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5120564020742744
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 149 training complete
# Cost on training data: 0.014761790239134308
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5129314601872739
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 150 training complete
# Cost on training data: 0.01463285184689611
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5142744847240577
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 151 training complete
# Cost on training data: 0.014506702148682589
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5154567864101702
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 152 training complete
# Cost on training data: 0.014387066080935611
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.519303616584464
# Accuracy on evaluation data: 8236 / 10000
#
# Epoch 153 training complete
# Cost on training data: 0.014262374389876823
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.519775537452171
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 154 training complete
# Cost on training data: 0.014144965409857086
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5222747559734444
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 155 training complete
# Cost on training data: 0.014026496424476662
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5218520944984784
# Accuracy on evaluation data: 8237 / 10000
#
# Epoch 156 training complete
# Cost on training data: 0.013909133119703865
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5232085921931346
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 157 training complete
# Cost on training data: 0.013791870305519361
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5234212493262043
# Accuracy on evaluation data: 8231 / 10000
#
# Epoch 158 training complete
# Cost on training data: 0.013708527423865795
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5267731744734458
# Accuracy on evaluation data: 8230 / 10000
#
# Epoch 159 training complete
# Cost on training data: 0.013572651208587538
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.526935403333182
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 160 training complete
# Cost on training data: 0.013462629043396655
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5282877431582573
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 161 training complete
# Cost on training data: 0.013378991424083863
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.530767354698435
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 162 training complete
# Cost on training data: 0.013249772522154993
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5307569997321164
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 163 training complete
# Cost on training data: 0.013152749886791085
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.531265732860321
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 164 training complete
# Cost on training data: 0.01304766747866784
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5329336094237993
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 165 training complete
# Cost on training data: 0.012942870690857195
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5338871198315862
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 166 training complete
# Cost on training data: 0.012844229821677822
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5353270798980614
# Accuracy on evaluation data: 8231 / 10000
#
# Epoch 167 training complete
# Cost on training data: 0.012746842246247803
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5373073680585623
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 168 training complete
# Cost on training data: 0.012653209505582146
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5378338937347085
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 169 training complete
# Cost on training data: 0.012561038107508948
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5379242636747255
# Accuracy on evaluation data: 8228 / 10000
#
# Epoch 170 training complete
# Cost on training data: 0.012467212383175512
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5399076474671676
# Accuracy on evaluation data: 8230 / 10000
#
# Epoch 171 training complete
# Cost on training data: 0.012375298222580508
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5406359779822798
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 172 training complete
# Cost on training data: 0.012275670260909366
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5433590695678283
# Accuracy on evaluation data: 8236 / 10000
#
# Epoch 173 training complete
# Cost on training data: 0.012187486211692421
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5449069779920888
# Accuracy on evaluation data: 8230 / 10000
#
# Epoch 174 training complete
# Cost on training data: 0.012096063780543388
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5456232422827152
# Accuracy on evaluation data: 8236 / 10000
#
# Epoch 175 training complete
# Cost on training data: 0.012009135025541825
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5464604325062057
# Accuracy on evaluation data: 8230 / 10000
#
# Epoch 176 training complete
# Cost on training data: 0.011922607026350202
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.548022864970067
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 177 training complete
# Cost on training data: 0.011837417811930116
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5493129110674868
# Accuracy on evaluation data: 8231 / 10000
#
# Epoch 178 training complete
# Cost on training data: 0.011755642395410644
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5504526602375908
# Accuracy on evaluation data: 8229 / 10000
#
# Epoch 179 training complete
# Cost on training data: 0.011671878595868044
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5508781598955934
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 180 training complete
# Cost on training data: 0.011588182181055551
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5524519611190855
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 181 training complete
# Cost on training data: 0.011510875883864364
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.552334690473448
# Accuracy on evaluation data: 8230 / 10000
#
# Epoch 182 training complete
# Cost on training data: 0.0114270775999769
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5545610567025117
# Accuracy on evaluation data: 8231 / 10000
#
# Epoch 183 training complete
# Cost on training data: 0.01135003795024532
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5552793821758863
# Accuracy on evaluation data: 8227 / 10000
#
# Epoch 184 training complete
# Cost on training data: 0.011268279634373905
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.557154986355888
# Accuracy on evaluation data: 8231 / 10000
#
# Epoch 185 training complete
# Cost on training data: 0.01118760654923035
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.558194070664996
# Accuracy on evaluation data: 8227 / 10000
#
# Epoch 186 training complete
# Cost on training data: 0.01111231308090317
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5600274147077222
# Accuracy on evaluation data: 8227 / 10000
#
# Epoch 187 training complete
# Cost on training data: 0.011038809250734227
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5601697153030578
# Accuracy on evaluation data: 8227 / 10000
#
# Epoch 188 training complete
# Cost on training data: 0.010959702190220357
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.561025035826791
# Accuracy on evaluation data: 8228 / 10000
#
# Epoch 189 training complete
# Cost on training data: 0.010885519441516828
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5632501020568574
# Accuracy on evaluation data: 8224 / 10000
#
# Epoch 190 training complete
# Cost on training data: 0.010813269961181718
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.564330416861971
# Accuracy on evaluation data: 8225 / 10000
#
# Epoch 191 training complete
# Cost on training data: 0.010744757297530811
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5654355233996329
# Accuracy on evaluation data: 8224 / 10000
#
# Epoch 192 training complete
# Cost on training data: 0.010668474166728607
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5664906679685013
# Accuracy on evaluation data: 8226 / 10000
#
# Epoch 193 training complete
# Cost on training data: 0.010595188043404992
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.567316150844993
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 194 training complete
# Cost on training data: 0.010523055418479879
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5679833912130199
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 195 training complete
# Cost on training data: 0.010453348196235493
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5704676815778313
# Accuracy on evaluation data: 8222 / 10000
#
# Epoch 196 training complete
# Cost on training data: 0.010383713081534062
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.571275647799974
# Accuracy on evaluation data: 8223 / 10000
#
# Epoch 197 training complete
# Cost on training data: 0.010312832973770546
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5727930892275113
# Accuracy on evaluation data: 8222 / 10000
#
# Epoch 198 training complete
# Cost on training data: 0.010240708528859634
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5731182492104832
# Accuracy on evaluation data: 8227 / 10000
#
# Epoch 199 training complete
# Cost on training data: 0.010171970080021254
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5748329497858138
# Accuracy on evaluation data: 8225 / 10000
#
# Epoch 200 training complete
# Cost on training data: 0.010101599254574566
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5764053248861334
# Accuracy on evaluation data: 8228 / 10000
#
# Epoch 201 training complete
# Cost on training data: 0.01003071149384906
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5769182849803414
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 202 training complete
# Cost on training data: 0.00996496358725183
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5780847885893416
# Accuracy on evaluation data: 8225 / 10000
#
# Epoch 203 training complete
# Cost on training data: 0.009896503890736593
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5775335352981288
# Accuracy on evaluation data: 8228 / 10000
#
# Epoch 204 training complete
# Cost on training data: 0.009828994927144211
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5792151032891963
# Accuracy on evaluation data: 8224 / 10000
#
# Epoch 205 training complete
# Cost on training data: 0.009765000656504524
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5809151064230949
# Accuracy on evaluation data: 8220 / 10000
#
# Epoch 206 training complete
# Cost on training data: 0.009694932300270387
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.581222046347023
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 207 training complete
# Cost on training data: 0.009629883946588827
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.582497351728571
# Accuracy on evaluation data: 8231 / 10000
#
# Epoch 208 training complete
# Cost on training data: 0.009565889115826402
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.58405837244593
# Accuracy on evaluation data: 8230 / 10000
#
# Epoch 209 training complete
# Cost on training data: 0.0095033745676071
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.586106290254586
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 210 training complete
# Cost on training data: 0.009439271368013216
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5857229973069016
# Accuracy on evaluation data: 8231 / 10000
#
# Epoch 211 training complete
# Cost on training data: 0.009377159839560932
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5864168087468131
# Accuracy on evaluation data: 8232 / 10000
#
# Epoch 212 training complete
# Cost on training data: 0.009315994183912317
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.588009273908457
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 213 training complete
# Cost on training data: 0.009255903117944757
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5892205723525217
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 214 training complete
# Cost on training data: 0.00919628410878665
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5894367711070498
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 215 training complete
# Cost on training data: 0.00913753690093393
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5916893979183906
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 216 training complete
# Cost on training data: 0.009077891717896268
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5927584130780803
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 217 training complete
# Cost on training data: 0.0090262889194682
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.594640018368491
# Accuracy on evaluation data: 8230 / 10000
#
# Epoch 218 training complete
# Cost on training data: 0.008963245525523468
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5942392091582434
# Accuracy on evaluation data: 8236 / 10000
#
# Epoch 219 training complete
# Cost on training data: 0.008908446228695943
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5967213070237452
# Accuracy on evaluation data: 8236 / 10000
#
# Epoch 220 training complete
# Cost on training data: 0.008849982495666294
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5969581455764164
# Accuracy on evaluation data: 8231 / 10000
#
# Epoch 221 training complete
# Cost on training data: 0.008794473167933348
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5973485802279
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 222 training complete
# Cost on training data: 0.0087446088098047
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5987016331733483
# Accuracy on evaluation data: 8230 / 10000
#
# Epoch 223 training complete
# Cost on training data: 0.00868950012899779
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.5997392076324957
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 224 training complete
# Cost on training data: 0.008631433531000205
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6004036432516229
# Accuracy on evaluation data: 8236 / 10000
#
# Epoch 225 training complete
# Cost on training data: 0.008577154532186866
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6012316433917655
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 226 training complete
# Cost on training data: 0.008523351751407114
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6018838798720445
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 227 training complete
# Cost on training data: 0.008471018683113849
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6030327918951417
# Accuracy on evaluation data: 8237 / 10000
#
# Epoch 228 training complete
# Cost on training data: 0.008419770896053442
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6037789789569334
# Accuracy on evaluation data: 8237 / 10000
#
# Epoch 229 training complete
# Cost on training data: 0.008367575266836288
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6051357285973684
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 230 training complete
# Cost on training data: 0.008317163763857808
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6050212095717948
# Accuracy on evaluation data: 8238 / 10000
#
# Epoch 231 training complete
# Cost on training data: 0.008268453384419663
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6055217666311976
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 232 training complete
# Cost on training data: 0.008218140376869172
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6067031389801956
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 233 training complete
# Cost on training data: 0.008168689141105676
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6079026939924927
# Accuracy on evaluation data: 8236 / 10000
#
# Epoch 234 training complete
# Cost on training data: 0.008121037542618498
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6085651196974686
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 235 training complete
# Cost on training data: 0.008072340672543152
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6097138266288764
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 236 training complete
# Cost on training data: 0.008024074883746343
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6106768693453326
# Accuracy on evaluation data: 8236 / 10000
#
# Epoch 237 training complete
# Cost on training data: 0.007979302765231283
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6115420643484502
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 238 training complete
# Cost on training data: 0.00793179708566734
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6122569688993538
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 239 training complete
# Cost on training data: 0.007887671738608026
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.613704401638454
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 240 training complete
# Cost on training data: 0.007844683674886862
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.615188024935076
# Accuracy on evaluation data: 8233 / 10000
#
# Epoch 241 training complete
# Cost on training data: 0.00779892246471212
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6150766751322718
# Accuracy on evaluation data: 8235 / 10000
#
# Epoch 242 training complete
# Cost on training data: 0.007755252262500394
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6159683665714917
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 243 training complete
# Cost on training data: 0.0077123494717554536
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.616205451970845
# Accuracy on evaluation data: 8234 / 10000
#
# Epoch 244 training complete
# Cost on training data: 0.007668273874032823
# ...
# Cost on training data: 0.005422934056877199
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6706301002004145
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 320 training complete
# Cost on training data: 0.005400680155876327
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6710897768162383
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 321 training complete
# Cost on training data: 0.005378720622630724
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.671996118927189
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 322 training complete
# Cost on training data: 0.005357074750349393
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6728877515406941
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 323 training complete
# Cost on training data: 0.005335548631528001
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6733158064080051
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 324 training complete
# Cost on training data: 0.005314377974174927
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6736195475733855
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 325 training complete
# Cost on training data: 0.005293454977582668
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6744017385498209
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 326 training complete
# Cost on training data: 0.005273159152682803
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6753916890420733
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 327 training complete
# Cost on training data: 0.0052524450032717575
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6757470172923423
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 328 training complete
# Cost on training data: 0.005232102653768192
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6763685677214135
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 329 training complete
# Cost on training data: 0.005211802947876752
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6769224502956943
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 330 training complete
# Cost on training data: 0.005191521554270979
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6773879054521468
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 331 training complete
# Cost on training data: 0.005171756744777146
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6782108671304483
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 332 training complete
# Cost on training data: 0.0051522023653476435
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6787935591613397
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 333 training complete
# Cost on training data: 0.005132841627369932
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6794853156515483
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 334 training complete
# Cost on training data: 0.005113755493370183
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.680224658277486
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 335 training complete
# Cost on training data: 0.005094718138617935
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6807737655699273
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 336 training complete
# Cost on training data: 0.005075925120264834
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6809991342046346
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 337 training complete
# Cost on training data: 0.005057371994675168
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6816412692299247
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 338 training complete
# Cost on training data: 0.005038689212439846
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6822584680443091
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 339 training complete
# Cost on training data: 0.005020565737359889
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6829239020648095
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 340 training complete
# Cost on training data: 0.005002259917313472
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6835667508265433
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 341 training complete
# Cost on training data: 0.004984186610637671
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6842513953274814
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 342 training complete
# Cost on training data: 0.004966485853739086
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6848794108370149
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 343 training complete
# Cost on training data: 0.004948707604311252
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6853928842319033
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 344 training complete
# Cost on training data: 0.004931158348036026
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6860216980633311
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 345 training complete
# Cost on training data: 0.004914047225434881
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6862097862207528
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 346 training complete
# Cost on training data: 0.0048965779998918855
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6869645872575363
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 347 training complete
# Cost on training data: 0.004879444956196705
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6878235078987356
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 348 training complete
# Cost on training data: 0.004862438327764389
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.688592551347209
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 349 training complete
# Cost on training data: 0.004845476808610544
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.688944171385419
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 350 training complete
# Cost on training data: 0.004828646260523929
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6894776483269385
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 351 training complete
# Cost on training data: 0.004812056667387123
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6899944692765714
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 352 training complete
# Cost on training data: 0.004795710115091261
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6903596848789375
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 353 training complete
# Cost on training data: 0.00477935038993704
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6909017419055832
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 354 training complete
# Cost on training data: 0.004763109500880652
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6913404843215942
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 355 training complete
# Cost on training data: 0.004746944162162189
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6922937780432818
# Accuracy on evaluation data: 8240 / 10000
#
# Epoch 356 training complete
# Cost on training data: 0.004730940601820852
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6928261204145831
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 357 training complete
# Cost on training data: 0.004715012518999648
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6931732082964581
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 358 training complete
# Cost on training data: 0.004699276780302792
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.693825542694237
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 359 training complete
# Cost on training data: 0.004683589834029533
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6942881322446102
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 360 training complete
# Cost on training data: 0.004668080070180114
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6947126136945603
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 361 training complete
# Cost on training data: 0.004652814012859304
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6949258682537034
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 362 training complete
# Cost on training data: 0.004637332094991006
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6957466659628717
# Accuracy on evaluation data: 8241 / 10000
#
# Epoch 363 training complete
# Cost on training data: 0.004622096353228845
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6964782743121163
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 364 training complete
# Cost on training data: 0.004607001794599739
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6971113493924188
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 365 training complete
# Cost on training data: 0.00459204194198886
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6974983888825972
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 366 training complete
# Cost on training data: 0.004577146682038402
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6980310033215202
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 367 training complete
# Cost on training data: 0.00456243698727343
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.698363701416559
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 368 training complete
# Cost on training data: 0.004547766270699717
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6988213559775538
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 369 training complete
# Cost on training data: 0.004533018627204578
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6994261382989497
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 370 training complete
# Cost on training data: 0.004518524449864912
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.6998461210734332
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 371 training complete
# Cost on training data: 0.004504128396304726
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7004351200408383
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 372 training complete
# Cost on training data: 0.004490006929306216
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7010273930397548
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 373 training complete
# Cost on training data: 0.004475707112188346
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7016637296532255
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 374 training complete
# Cost on training data: 0.004461486308887665
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7022324928987795
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 375 training complete
# Cost on training data: 0.004447475006936599
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7029938173037267
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 376 training complete
# Cost on training data: 0.004433480322826564
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7031428732415053
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 377 training complete
# Cost on training data: 0.004419642620850631
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7036731476717435
# Accuracy on evaluation data: 8242 / 10000
#
# Epoch 378 training complete
# Cost on training data: 0.004405990802427871
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7042946029676904
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 379 training complete
# Cost on training data: 0.0043922488645852815
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.704366270719843
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 380 training complete
# Cost on training data: 0.004378626833874719
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7050866487969383
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 381 training complete
# Cost on training data: 0.004365099013981847
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7058401147404547
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 382 training complete
# Cost on training data: 0.004351658385074124
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7062631954878316
# Accuracy on evaluation data: 8243 / 10000
#
# Epoch 383 training complete
# Cost on training data: 0.004338461140201115
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7068211364244261
# Accuracy on evaluation data: 8245 / 10000
#
# Epoch 384 training complete
# Cost on training data: 0.00432515180897141
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7071786927060255
# Accuracy on evaluation data: 8245 / 10000
#
# Epoch 385 training complete
# Cost on training data: 0.004312039956118345
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7077978209071902
# Accuracy on evaluation data: 8246 / 10000
#
# Epoch 386 training complete
# Cost on training data: 0.004298931826633183
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7080769181939524
# Accuracy on evaluation data: 8246 / 10000
#
# Epoch 387 training complete
# Cost on training data: 0.004285863260336805
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.708678720547626
# Accuracy on evaluation data: 8247 / 10000
#
# Epoch 388 training complete
# Cost on training data: 0.004272932697615459
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7091265909875133
# Accuracy on evaluation data: 8247 / 10000
#
# Epoch 389 training complete
# Cost on training data: 0.004260080978237614
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7099078872989237
# Accuracy on evaluation data: 8246 / 10000
#
# Epoch 390 training complete
# Cost on training data: 0.004247539025379889
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7107032888855767
# Accuracy on evaluation data: 8245 / 10000
#
# Epoch 391 training complete
# Cost on training data: 0.004234716858580699
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7110793800505681
# Accuracy on evaluation data: 8247 / 10000
#
# Epoch 392 training complete
# Cost on training data: 0.004222129915441808
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7115998613961831
# Accuracy on evaluation data: 8247 / 10000
#
# Epoch 393 training complete
# Cost on training data: 0.004209522608313673
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.711761133746168
# Accuracy on evaluation data: 8247 / 10000
#
# Epoch 394 training complete
# Cost on training data: 0.004197055766285211
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7121060081196278
# Accuracy on evaluation data: 8244 / 10000
#
# Epoch 395 training complete
# Cost on training data: 0.0041847611416577874
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7128247348411842
# Accuracy on evaluation data: 8248 / 10000
#
# Epoch 396 training complete
# Cost on training data: 0.004172389636025819
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.71322738150423
# Accuracy on evaluation data: 8248 / 10000
#
# Epoch 397 training complete
# Cost on training data: 0.004160083347986036
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7137964452885435
# Accuracy on evaluation data: 8248 / 10000
#
# Epoch 398 training complete
# Cost on training data: 0.0041478191673042205
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7141385943516114
# Accuracy on evaluation data: 8249 / 10000
#
# Epoch 399 training complete
# Cost on training data: 0.004135691358476162
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.7143890113249696
# Accuracy on evaluation data: 8248 / 10000

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.use("nbagg")

# %%
plt.plot(np.arange(200,400),training_cost[200:])
plt.xlabel("Epoch")
plt.ylabel("Cost")
plt.title("Cost on training data")
plt.show()
# Out:
# <div id='eaef4d9f-1421-46e5-8106-08de69125904'></div>

# %%
plt.plot(np.arange(200,400),evaluation_accuracy[200:])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy on test data")
plt.show()
# Out:
# <div id='d6ac051b-33df-4cc6-80de-8cd3a8db6aea'></div>

# %%
plt.plot(np.arange(400),evaluation_cost)
plt.xlabel("Epoch")
plt.title("Cost on test data")
plt.show()
# Out:
# <div id='f90e3f5f-7bd8-4117-99cd-9fc4fff39f94'></div>

# %%
plt.plot(np.arange(400),training_accuracy)
plt.xlabel("Epoch")
plt.title("Acuuracy on training data")
plt.show()
# Out:
# <div id='3f1d49dd-421b-4bae-a64a-dc39afcc2e1a'></div>

# %%
training_data, validation_Data, test_data = load_data_wrapper()
net = Network([784, 30, 10], cost=CrossEntropyCost)
net.large_weight_initializer()
evaluation_cost, evaluation_accuracy, training_cost, training_accuracy = net.SGD(
    training_data,
    30, 10, 0.5,
    evaluation_data=test_data,
    monitor_evaluation_accuracy=True,
    monitor_training_cost=False,
    monitor_evaluation_cost=False,
    monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Accuracy on training data: 45191 / 50000
# Accuracy on evaluation data: 9087 / 10000
#
# Epoch 1 training complete
# Accuracy on training data: 46400 / 50000
# Accuracy on evaluation data: 9274 / 10000
#
# Epoch 2 training complete
# Accuracy on training data: 46976 / 50000
# Accuracy on evaluation data: 9342 / 10000
#
# Epoch 3 training complete
# Accuracy on training data: 47126 / 50000
# Accuracy on evaluation data: 9357 / 10000
#
# Epoch 4 training complete
# Accuracy on training data: 47302 / 50000
# Accuracy on evaluation data: 9365 / 10000
#
# Epoch 5 training complete
# Accuracy on training data: 47558 / 50000
# Accuracy on evaluation data: 9422 / 10000
#
# Epoch 6 training complete
# Accuracy on training data: 47749 / 50000
# Accuracy on evaluation data: 9451 / 10000
#
# Epoch 7 training complete
# Accuracy on training data: 47875 / 50000
# Accuracy on evaluation data: 9446 / 10000
#
# Epoch 8 training complete
# Accuracy on training data: 47876 / 50000
# Accuracy on evaluation data: 9469 / 10000
#
# Epoch 9 training complete
# Accuracy on training data: 47990 / 50000
# Accuracy on evaluation data: 9479 / 10000
#
# Epoch 10 training complete
# Accuracy on training data: 48119 / 50000
# Accuracy on evaluation data: 9469 / 10000
#
# Epoch 11 training complete
# Accuracy on training data: 48088 / 50000
# Accuracy on evaluation data: 9464 / 10000
#
# Epoch 12 training complete
# Accuracy on training data: 48254 / 50000
# Accuracy on evaluation data: 9486 / 10000
#
# Epoch 13 training complete
# Accuracy on training data: 48392 / 50000
# Accuracy on evaluation data: 9511 / 10000
#
# Epoch 14 training complete
# Accuracy on training data: 48342 / 50000
# Accuracy on evaluation data: 9491 / 10000
#
# Epoch 15 training complete
# Accuracy on training data: 48464 / 50000
# Accuracy on evaluation data: 9522 / 10000
#
# Epoch 16 training complete
# Accuracy on training data: 48435 / 50000
# Accuracy on evaluation data: 9481 / 10000
#
# Epoch 17 training complete
# Accuracy on training data: 48456 / 50000
# Accuracy on evaluation data: 9483 / 10000
#
# Epoch 18 training complete
# Accuracy on training data: 48508 / 50000
# Accuracy on evaluation data: 9504 / 10000
#
# Epoch 19 training complete
# Accuracy on training data: 48584 / 50000
# Accuracy on evaluation data: 9503 / 10000
#
# Epoch 20 training complete
# Accuracy on training data: 48572 / 50000
# Accuracy on evaluation data: 9523 / 10000
#
# Epoch 21 training complete
# Accuracy on training data: 48700 / 50000
# Accuracy on evaluation data: 9513 / 10000
#
# Epoch 22 training complete
# Accuracy on training data: 48708 / 50000
# Accuracy on evaluation data: 9509 / 10000
#
# Epoch 23 training complete
# Accuracy on training data: 48765 / 50000
# Accuracy on evaluation data: 9519 / 10000
#
# Epoch 24 training complete
# Accuracy on training data: 48797 / 50000
# Accuracy on evaluation data: 9524 / 10000
#
# Epoch 25 training complete
# Accuracy on training data: 48728 / 50000
# Accuracy on evaluation data: 9513 / 10000
#
# Epoch 26 training complete
# Accuracy on training data: 48767 / 50000
# Accuracy on evaluation data: 9519 / 10000
#
# Epoch 27 training complete
# Accuracy on training data: 48647 / 50000
# Accuracy on evaluation data: 9492 / 10000
#
# Epoch 28 training complete
# Accuracy on training data: 48917 / 50000
# Accuracy on evaluation data: 9526 / 10000
#
# Epoch 29 training complete
# Accuracy on training data: 48941 / 50000
# Accuracy on evaluation data: 9515 / 10000

# %%
mpl.style.use("seaborn-white")
plt.plot(np.arange(30),np.array(training_accuracy)/50000,label="Training Accuracy")
plt.plot(np.arange(30),np.array(evaluation_accuracy)/10000,label="Test Accuracy")
plt.legend()
plt.show()
# Out:
# <div id='2409dcbb-be64-4226-bea7-a01c414ff5eb'></div>

# %%
mpl.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
training_data, validation_Data, test_data = load_data_wrapper()
net = Network([784, 30, 10], cost=CrossEntropyCost)
net.large_weight_initializer()
evaluation_cost, evaluation_accuracy, training_cost, training_accuracy = net.SGD(
    training_data[:1000],
    400, 10, 0.5,
    lmbda=0.1,
    evaluation_data=test_data,
    monitor_evaluation_accuracy=True,
    monitor_training_cost=True,
    monitor_evaluation_cost=True,
    monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Cost on training data: 2.9458607989396164
# Accuracy on training data: 674 / 1000
# Cost on evaluation data: 2.248197884806606
# Accuracy on evaluation data: 5755 / 10000
#
# Epoch 1 training complete
# Cost on training data: 2.4735066209172896
# Accuracy on training data: 789 / 1000
# Cost on evaluation data: 1.8724051507852524
# Accuracy on evaluation data: 6671 / 10000
#
# Epoch 2 training complete
# Cost on training data: 2.2505582173361667
# Accuracy on training data: 842 / 1000
# Cost on evaluation data: 1.7311059866344827
# Accuracy on evaluation data: 7027 / 10000
#
# Epoch 3 training complete
# Cost on training data: 2.0682669791817703
# Accuracy on training data: 873 / 1000
# Cost on evaluation data: 1.596023795259689
# Accuracy on evaluation data: 7317 / 10000
#
# Epoch 4 training complete
# Cost on training data: 1.9323653693018321
# Accuracy on training data: 901 / 1000
# Cost on evaluation data: 1.5141287512330737
# Accuracy on evaluation data: 7504 / 10000
#
# Epoch 5 training complete
# Cost on training data: 1.8433457717794997
# Accuracy on training data: 914 / 1000
# Cost on evaluation data: 1.472720812123193
# Accuracy on evaluation data: 7622 / 10000
#
# Epoch 6 training complete
# Cost on training data: 1.7426849599243148
# Accuracy on training data: 931 / 1000
# Cost on evaluation data: 1.4101232484697166
# Accuracy on evaluation data: 7740 / 10000
#
# Epoch 7 training complete
# Cost on training data: 1.6713068928641754
# Accuracy on training data: 945 / 1000
# Cost on evaluation data: 1.3701719401149022
# Accuracy on evaluation data: 7809 / 10000
#
# Epoch 8 training complete
# Cost on training data: 1.6047398404461644
# Accuracy on training data: 955 / 1000
# Cost on evaluation data: 1.3342789190934063
# Accuracy on evaluation data: 7948 / 10000
#
# Epoch 9 training complete
# Cost on training data: 1.5597603773709685
# Accuracy on training data: 963 / 1000
# Cost on evaluation data: 1.346403130453886
# Accuracy on evaluation data: 7930 / 10000
#
# Epoch 10 training complete
# Cost on training data: 1.4944546161423158
# Accuracy on training data: 960 / 1000
# Cost on evaluation data: 1.28153292504166
# Accuracy on evaluation data: 8057 / 10000
#
# Epoch 11 training complete
# Cost on training data: 1.4580391127673917
# Accuracy on training data: 967 / 1000
# Cost on evaluation data: 1.2817900129569477
# Accuracy on evaluation data: 8068 / 10000
#
# Epoch 12 training complete
# Cost on training data: 1.4287697025531816
# Accuracy on training data: 966 / 1000
# Cost on evaluation data: 1.2821272414449887
# Accuracy on evaluation data: 8072 / 10000
#
# Epoch 13 training complete
# Cost on training data: 1.389778096611034
# Accuracy on training data: 975 / 1000
# Cost on evaluation data: 1.2667040059153518
# Accuracy on evaluation data: 8152 / 10000
#
# Epoch 14 training complete
# Cost on training data: 1.366879271398576
# Accuracy on training data: 973 / 1000
# Cost on evaluation data: 1.2717700002843353
# Accuracy on evaluation data: 8116 / 10000
#
# Epoch 15 training complete
# Cost on training data: 1.334353405532739
# Accuracy on training data: 975 / 1000
# Cost on evaluation data: 1.2619157279948223
# Accuracy on evaluation data: 8134 / 10000
#
# Epoch 16 training complete
# Cost on training data: 1.302841746209534
# Accuracy on training data: 977 / 1000
# Cost on evaluation data: 1.238434636462659
# Accuracy on evaluation data: 8188 / 10000
#
# Epoch 17 training complete
# Cost on training data: 1.2754149152392895
# Accuracy on training data: 982 / 1000
# Cost on evaluation data: 1.2317452878563027
# Accuracy on evaluation data: 8199 / 10000
#
# Epoch 18 training complete
# Cost on training data: 1.249849223184203
# Accuracy on training data: 984 / 1000
# Cost on evaluation data: 1.2308081188297395
# Accuracy on evaluation data: 8224 / 10000
#
# Epoch 19 training complete
# Cost on training data: 1.2300117097910528
# Accuracy on training data: 984 / 1000
# Cost on evaluation data: 1.2197967415157729
# Accuracy on evaluation data: 8239 / 10000
#
# Epoch 20 training complete
# Cost on training data: 1.2060258029094868
# Accuracy on training data: 984 / 1000
# Cost on evaluation data: 1.213801612005916
# Accuracy on evaluation data: 8254 / 10000
#
# Epoch 21 training complete
# Cost on training data: 1.1854286229015867
# Accuracy on training data: 986 / 1000
# Cost on evaluation data: 1.2192021574216134
# Accuracy on evaluation data: 8253 / 10000
#
# Epoch 22 training complete
# Cost on training data: 1.1713111402205185
# Accuracy on training data: 988 / 1000
# Cost on evaluation data: 1.226628256046492
# Accuracy on evaluation data: 8252 / 10000
#
# Epoch 23 training complete
# Cost on training data: 1.1476736705072594
# Accuracy on training data: 986 / 1000
# Cost on evaluation data: 1.2103713050409948
# Accuracy on evaluation data: 8268 / 10000
#
# Epoch 24 training complete
# Cost on training data: 1.1332204874428053
# Accuracy on training data: 988 / 1000
# Cost on evaluation data: 1.2188757882764614
# Accuracy on evaluation data: 8283 / 10000
#
# Epoch 25 training complete
# Cost on training data: 1.1182498527269098
# Accuracy on training data: 989 / 1000
# Cost on evaluation data: 1.2060929124115871
# Accuracy on evaluation data: 8289 / 10000
#
# Epoch 26 training complete
# Cost on training data: 1.1000740208614477
# Accuracy on training data: 991 / 1000
# Cost on evaluation data: 1.213539297423324
# Accuracy on evaluation data: 8303 / 10000
#
# Epoch 27 training complete
# Cost on training data: 1.0847685248853758
# Accuracy on training data: 992 / 1000
# Cost on evaluation data: 1.2148779645283074
# Accuracy on evaluation data: 8289 / 10000
#
# Epoch 28 training complete
# Cost on training data: 1.0702212226689363
# Accuracy on training data: 993 / 1000
# Cost on evaluation data: 1.2069361184827179
# Accuracy on evaluation data: 8310 / 10000
#
# Epoch 29 training complete
# Cost on training data: 1.0582131865116233
# Accuracy on training data: 993 / 1000
# Cost on evaluation data: 1.2032442973337532
# Accuracy on evaluation data: 8306 / 10000
#
# Epoch 30 training complete
# Cost on training data: 1.04401345572194
# Accuracy on training data: 995 / 1000
# Cost on evaluation data: 1.199424825557862
# Accuracy on evaluation data: 8317 / 10000
#
# Epoch 31 training complete
# Cost on training data: 1.0329430747294785
# Accuracy on training data: 994 / 1000
# Cost on evaluation data: 1.2062568697035745
# Accuracy on evaluation data: 8304 / 10000
#
# Epoch 32 training complete
# Cost on training data: 1.0203740571604472
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 1.2049667598904212
# Accuracy on evaluation data: 8330 / 10000
#
# Epoch 33 training complete
# Cost on training data: 1.0081509719726867
# Accuracy on training data: 995 / 1000
# Cost on evaluation data: 1.2050138501292362
# Accuracy on evaluation data: 8321 / 10000
#
# Epoch 34 training complete
# Cost on training data: 0.9973149917676881
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 1.2002650453353274
# Accuracy on evaluation data: 8339 / 10000
#
# Epoch 35 training complete
# Cost on training data: 0.985607815627068
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 1.2091344048130792
# Accuracy on evaluation data: 8325 / 10000
#
# Epoch 36 training complete
# Cost on training data: 0.9741658512914536
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 1.2045511073691155
# Accuracy on evaluation data: 8332 / 10000
#
# Epoch 37 training complete
# Cost on training data: 0.9633624779030916
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 1.2027319250230695
# Accuracy on evaluation data: 8333 / 10000
#
# Epoch 38 training complete
# Cost on training data: 0.9529613718900185
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 1.2007874614325467
# Accuracy on evaluation data: 8355 / 10000
#
# Epoch 39 training complete
# Cost on training data: 0.9412752594111009
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 1.1962678114262615
# Accuracy on evaluation data: 8366 / 10000
#
# Epoch 40 training complete
# Cost on training data: 0.9315188111881819
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.1971710443172485
# Accuracy on evaluation data: 8377 / 10000
#
# Epoch 41 training complete
# Cost on training data: 0.9217471652573328
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.191898191845234
# Accuracy on evaluation data: 8372 / 10000
#
# Epoch 42 training complete
# Cost on training data: 0.9120070857276091
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.1989638164000878
# Accuracy on evaluation data: 8375 / 10000
#
# Epoch 43 training complete
# Cost on training data: 0.9028675972045171
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.1902104271042102
# Accuracy on evaluation data: 8386 / 10000
#
# Epoch 44 training complete
# Cost on training data: 0.8939613158417045
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.1856359569780073
# Accuracy on evaluation data: 8393 / 10000
#
# Epoch 45 training complete
# Cost on training data: 0.8848929572413323
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.187055557031881
# Accuracy on evaluation data: 8403 / 10000
#
# Epoch 46 training complete
# Cost on training data: 0.8768715689387017
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 1.1820343620300668
# Accuracy on evaluation data: 8404 / 10000
#
# Epoch 47 training complete
# Cost on training data: 0.8675470153280676
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 1.1889128957603763
# Accuracy on evaluation data: 8407 / 10000
#
# Epoch 48 training complete
# Cost on training data: 0.8589628220771277
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 1.1856427749173186
# Accuracy on evaluation data: 8413 / 10000
#
# Epoch 49 training complete
# Cost on training data: 0.850815548911741
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.187786814771836
# Accuracy on evaluation data: 8413 / 10000
#
# Epoch 50 training complete
# Cost on training data: 0.8428020334757673
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.1781137474449537
# Accuracy on evaluation data: 8417 / 10000
#
# Epoch 51 training complete
# Cost on training data: 0.8349150384933703
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.1847947320152048
# Accuracy on evaluation data: 8419 / 10000
#
# Epoch 52 training complete
# Cost on training data: 0.8270257018680188
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.178316800569935
# Accuracy on evaluation data: 8418 / 10000
#
# Epoch 53 training complete
# Cost on training data: 0.8193484121530324
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.181907723630237
# Accuracy on evaluation data: 8429 / 10000
#
# Epoch 54 training complete
# Cost on training data: 0.8113489353451673
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.176086806667719
# Accuracy on evaluation data: 8433 / 10000
#
# Epoch 55 training complete
# Cost on training data: 0.8037794044412074
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.1794021751679848
# Accuracy on evaluation data: 8431 / 10000
#
# Epoch 56 training complete
# Cost on training data: 0.7965297073122268
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.1803955290216477
# Accuracy on evaluation data: 8439 / 10000
#
# Epoch 57 training complete
# Cost on training data: 0.7892272278343743
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 1.1842537430727424
# Accuracy on evaluation data: 8434 / 10000
#
# Epoch 58 training complete
# Cost on training data: 0.7817315171116557
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1822816930023285
# Accuracy on evaluation data: 8442 / 10000
#
# Epoch 59 training complete
# Cost on training data: 0.7745708751302885
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1711721676862372
# Accuracy on evaluation data: 8434 / 10000
#
# Epoch 60 training complete
# Cost on training data: 0.7672392312880743
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1778431243391563
# Accuracy on evaluation data: 8442 / 10000
#
# Epoch 61 training complete
# Cost on training data: 0.7601510713973393
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1731852921286599
# Accuracy on evaluation data: 8446 / 10000
#
# Epoch 62 training complete
# Cost on training data: 0.7533861218940656
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.168806124635382
# Accuracy on evaluation data: 8460 / 10000
#
# Epoch 63 training complete
# Cost on training data: 0.7469288048379518
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1702084532433241
# Accuracy on evaluation data: 8461 / 10000
#
# Epoch 64 training complete
# Cost on training data: 0.7397531124451479
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1666410812442953
# Accuracy on evaluation data: 8454 / 10000
#
# Epoch 65 training complete
# Cost on training data: 0.7332894479764464
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1607656081191453
# Accuracy on evaluation data: 8460 / 10000
#
# Epoch 66 training complete
# Cost on training data: 0.726686504475459
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1693678260051323
# Accuracy on evaluation data: 8447 / 10000
#
# Epoch 67 training complete
# Cost on training data: 0.720466299609239
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1594085622439412
# Accuracy on evaluation data: 8473 / 10000
#
# Epoch 68 training complete
# Cost on training data: 0.713818340721861
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.158185955027782
# Accuracy on evaluation data: 8469 / 10000
#
# Epoch 69 training complete
# Cost on training data: 0.7074618524140142
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1612176926103437
# Accuracy on evaluation data: 8478 / 10000
#
# Epoch 70 training complete
# Cost on training data: 0.7016340129781931
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1520397896980703
# Accuracy on evaluation data: 8483 / 10000
#
# Epoch 71 training complete
# Cost on training data: 0.6952768358345983
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1531614759776398
# Accuracy on evaluation data: 8489 / 10000
#
# Epoch 72 training complete
# Cost on training data: 0.689158762393338
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1590088606359326
# Accuracy on evaluation data: 8472 / 10000
#
# Epoch 73 training complete
# Cost on training data: 0.6831092679623778
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1566086174974153
# Accuracy on evaluation data: 8488 / 10000
#
# Epoch 74 training complete
# Cost on training data: 0.6771423573200679
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.15389171332849
# Accuracy on evaluation data: 8487 / 10000
#
# Epoch 75 training complete
# Cost on training data: 0.67155122944674
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1559080275935054
# Accuracy on evaluation data: 8499 / 10000
#
# Epoch 76 training complete
# Cost on training data: 0.665530790171997
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1407507768806853
# Accuracy on evaluation data: 8499 / 10000
#
# Epoch 77 training complete
# Cost on training data: 0.6597842966538526
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1475759537536578
# Accuracy on evaluation data: 8496 / 10000
#
# Epoch 78 training complete
# Cost on training data: 0.6540533456638797
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.140450772122947
# Accuracy on evaluation data: 8496 / 10000
#
# Epoch 79 training complete
# Cost on training data: 0.6486905903760358
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1427658452316347
# Accuracy on evaluation data: 8489 / 10000
#
# Epoch 80 training complete
# Cost on training data: 0.643097837600364
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1363053304783144
# Accuracy on evaluation data: 8502 / 10000
#
# Epoch 81 training complete
# Cost on training data: 0.6374867753498819
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1426199471199219
# Accuracy on evaluation data: 8505 / 10000
#
# Epoch 82 training complete
# Cost on training data: 0.6321834979301588
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1407078203240544
# Accuracy on evaluation data: 8490 / 10000
#
# Epoch 83 training complete
# Cost on training data: 0.6268486191185592
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.135439813924724
# Accuracy on evaluation data: 8510 / 10000
#
# Epoch 84 training complete
# Cost on training data: 0.6215428128826364
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1279543741768063
# Accuracy on evaluation data: 8528 / 10000
#
# Epoch 85 training complete
# Cost on training data: 0.6162375441600695
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1332810619543603
# Accuracy on evaluation data: 8512 / 10000
#
# Epoch 86 training complete
# Cost on training data: 0.6112278559502963
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.133711382025525
# Accuracy on evaluation data: 8505 / 10000
#
# Epoch 87 training complete
# Cost on training data: 0.6058764417939931
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.131524629861151
# Accuracy on evaluation data: 8511 / 10000
#
# Epoch 88 training complete
# Cost on training data: 0.601051447485322
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1253497136033894
# Accuracy on evaluation data: 8522 / 10000
#
# Epoch 89 training complete
# Cost on training data: 0.59584737651961
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1250439218871988
# Accuracy on evaluation data: 8533 / 10000
#
# Epoch 90 training complete
# Cost on training data: 0.5910888083148295
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1141668413513661
# Accuracy on evaluation data: 8524 / 10000
#
# Epoch 91 training complete
# Cost on training data: 0.5860669155514356
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.116511353978444
# Accuracy on evaluation data: 8532 / 10000
#
# Epoch 92 training complete
# Cost on training data: 0.581016426823258
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1177242072639182
# Accuracy on evaluation data: 8526 / 10000
#
# Epoch 93 training complete
# Cost on training data: 0.5765173025558805
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1159643791172968
# Accuracy on evaluation data: 8535 / 10000
#
# Epoch 94 training complete
# Cost on training data: 0.5716839210309205
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1168467100474562
# Accuracy on evaluation data: 8535 / 10000
#
# Epoch 95 training complete
# Cost on training data: 0.5668654600578205
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1076692587568795
# Accuracy on evaluation data: 8547 / 10000
#
# Epoch 96 training complete
# Cost on training data: 0.5623028734596908
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1040093286497232
# Accuracy on evaluation data: 8534 / 10000
#
# Epoch 97 training complete
# Cost on training data: 0.5575511125455492
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1082657984116329
# Accuracy on evaluation data: 8521 / 10000
#
# Epoch 98 training complete
# Cost on training data: 0.5529453364748543
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1039811353452982
# Accuracy on evaluation data: 8529 / 10000
#
# Epoch 99 training complete
# Cost on training data: 0.5484262500058954
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.1048492750921217
# Accuracy on evaluation data: 8537 / 10000
#
# Epoch 100 training complete
# Cost on training data: 0.5439191905725689
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0993006461701356
# Accuracy on evaluation data: 8550 / 10000
#
# Epoch 101 training complete
# Cost on training data: 0.5395345441645594
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0971860706634866
# Accuracy on evaluation data: 8540 / 10000
#
# Epoch 102 training complete
# Cost on training data: 0.5351003533555713
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0980747643641844
# Accuracy on evaluation data: 8535 / 10000
#
# Epoch 103 training complete
# Cost on training data: 0.5306701124644996
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0943302529684857
# Accuracy on evaluation data: 8549 / 10000
#
# Epoch 104 training complete
# Cost on training data: 0.5263050575582616
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0908743627626811
# Accuracy on evaluation data: 8550 / 10000
#
# Epoch 105 training complete
# Cost on training data: 0.5222756218440373
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.088592880753784
# Accuracy on evaluation data: 8558 / 10000
#
# Epoch 106 training complete
# Cost on training data: 0.5178712197047783
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0889860377241782
# Accuracy on evaluation data: 8546 / 10000
#
# Epoch 107 training complete
# Cost on training data: 0.5138168930697018
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0864420078094663
# Accuracy on evaluation data: 8550 / 10000
#
# Epoch 108 training complete
# Cost on training data: 0.5095163431618153
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0851314881108785
# Accuracy on evaluation data: 8549 / 10000
#
# Epoch 109 training complete
# Cost on training data: 0.5052934988728466
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0832527280077044
# Accuracy on evaluation data: 8554 / 10000
#
# Epoch 110 training complete
# Cost on training data: 0.5012558977838917
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0794899074138409
# Accuracy on evaluation data: 8560 / 10000
#
# Epoch 111 training complete
# Cost on training data: 0.497279683285829
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0790768698357933
# Accuracy on evaluation data: 8558 / 10000
#
# Epoch 112 training complete
# Cost on training data: 0.49318635764710844
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0735874471314983
# Accuracy on evaluation data: 8564 / 10000
#
# Epoch 113 training complete
# Cost on training data: 0.48952423340361884
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0823839912004602
# Accuracy on evaluation data: 8555 / 10000
#
# Epoch 114 training complete
# Cost on training data: 0.4855349862145627
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0731134608288342
# Accuracy on evaluation data: 8575 / 10000
#
# Epoch 115 training complete
# Cost on training data: 0.48140665712323455
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0705921540713565
# Accuracy on evaluation data: 8572 / 10000
#
# Epoch 116 training complete
# Cost on training data: 0.47780171106483466
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0727718449776242
# Accuracy on evaluation data: 8560 / 10000
#
# Epoch 117 training complete
# Cost on training data: 0.4737419714537697
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0709077878233586
# Accuracy on evaluation data: 8569 / 10000
#
# Epoch 118 training complete
# Cost on training data: 0.4698993177582541
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.065089763497978
# Accuracy on evaluation data: 8579 / 10000
#
# Epoch 119 training complete
# Cost on training data: 0.46615803899675007
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0619134799712733
# Accuracy on evaluation data: 8576 / 10000
#
# Epoch 120 training complete
# Cost on training data: 0.4623918915812671
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0672581106417374
# Accuracy on evaluation data: 8581 / 10000
#
# Epoch 121 training complete
# Cost on training data: 0.4586903578429423
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0606504852544139
# Accuracy on evaluation data: 8570 / 10000
#
# Epoch 122 training complete
# Cost on training data: 0.4550305335740893
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.055075686339686
# Accuracy on evaluation data: 8588 / 10000
#
# Epoch 123 training complete
# Cost on training data: 0.45135302095301155
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0520037932967028
# Accuracy on evaluation data: 8581 / 10000
#
# Epoch 124 training complete
# Cost on training data: 0.44779449779114305
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0525678854278655
# Accuracy on evaluation data: 8574 / 10000
#
# Epoch 125 training complete
# Cost on training data: 0.44438668267206716
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0528185291483698
# Accuracy on evaluation data: 8589 / 10000
#
# Epoch 126 training complete
# Cost on training data: 0.440751008969631
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0501232278662018
# Accuracy on evaluation data: 8595 / 10000
#
# Epoch 127 training complete
# Cost on training data: 0.4372628481282777
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0516036103237993
# Accuracy on evaluation data: 8583 / 10000
#
# Epoch 128 training complete
# Cost on training data: 0.4339679528947296
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0496770141240541
# Accuracy on evaluation data: 8590 / 10000
#
# Epoch 129 training complete
# Cost on training data: 0.43052854301654764
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0460668338667078
# Accuracy on evaluation data: 8588 / 10000
#
# Epoch 130 training complete
# Cost on training data: 0.4271069317588421
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0423632814205195
# Accuracy on evaluation data: 8590 / 10000
#
# Epoch 131 training complete
# Cost on training data: 0.4239148730810212
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0493688845560571
# Accuracy on evaluation data: 8582 / 10000
#
# Epoch 132 training complete
# Cost on training data: 0.42045972799881864
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0377187821383762
# Accuracy on evaluation data: 8603 / 10000
#
# Epoch 133 training complete
# Cost on training data: 0.4173437994677277
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0379216710657722
# Accuracy on evaluation data: 8595 / 10000
#
# Epoch 134 training complete
# Cost on training data: 0.4140145088213035
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0337304801809941
# Accuracy on evaluation data: 8607 / 10000
#
# Epoch 135 training complete
# Cost on training data: 0.41076175402329973
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0326350587260058
# Accuracy on evaluation data: 8602 / 10000
#
# Epoch 136 training complete
# Cost on training data: 0.4077576484368493
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.034042988308061
# Accuracy on evaluation data: 8607 / 10000
#
# Epoch 137 training complete
# Cost on training data: 0.4046155452225018
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.030302877959961
# Accuracy on evaluation data: 8602 / 10000
#
# Epoch 138 training complete
# Cost on training data: 0.40156522347315676
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0258605080061185
# Accuracy on evaluation data: 8617 / 10000
#
# Epoch 139 training complete
# Cost on training data: 0.39850789616196675
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0248178411457884
# Accuracy on evaluation data: 8612 / 10000
#
# Epoch 140 training complete
# Cost on training data: 0.3954448390389383
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0217170079838076
# Accuracy on evaluation data: 8615 / 10000
#
# Epoch 141 training complete
# Cost on training data: 0.3925839461546803
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0248982773526385
# Accuracy on evaluation data: 8616 / 10000
#
# Epoch 142 training complete
# Cost on training data: 0.38951320085280366
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.019751165981248
# Accuracy on evaluation data: 8609 / 10000
#
# Epoch 143 training complete
# Cost on training data: 0.38659000623795975
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0185783326700208
# Accuracy on evaluation data: 8612 / 10000
#
# Epoch 144 training complete
# Cost on training data: 0.38356493619996
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0136003943004315
# Accuracy on evaluation data: 8631 / 10000
#
# Epoch 145 training complete
# Cost on training data: 0.38071309815405646
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0112389509473307
# Accuracy on evaluation data: 8621 / 10000
#
# Epoch 146 training complete
# Cost on training data: 0.3779352432237691
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0081174258821703
# Accuracy on evaluation data: 8624 / 10000
#
# Epoch 147 training complete
# Cost on training data: 0.3750710473668308
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0082571779729723
# Accuracy on evaluation data: 8632 / 10000
#
# Epoch 148 training complete
# Cost on training data: 0.37225376062460575
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.007208529265962
# Accuracy on evaluation data: 8630 / 10000
#
# Epoch 149 training complete
# Cost on training data: 0.36949804376209494
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0038626888733087
# Accuracy on evaluation data: 8629 / 10000
#
# Epoch 150 training complete
# Cost on training data: 0.36711375316304923
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 1.0098326947472789
# Accuracy on evaluation data: 8618 / 10000
#
# Epoch 151 training complete
# Cost on training data: 0.3641973517954186
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9986134130159143
# Accuracy on evaluation data: 8635 / 10000
#
# Epoch 152 training complete
# Cost on training data: 0.36142850495419215
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9987531179272178
# Accuracy on evaluation data: 8643 / 10000
#
# Epoch 153 training complete
# Cost on training data: 0.35871364467712985
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9993645177475333
# Accuracy on evaluation data: 8621 / 10000
#
# Epoch 154 training complete
# Cost on training data: 0.3561078161763879
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9978428843723567
# Accuracy on evaluation data: 8637 / 10000
#
# Epoch 155 training complete
# Cost on training data: 0.3534701996229348
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9948746391397445
# Accuracy on evaluation data: 8629 / 10000
#
# Epoch 156 training complete
# Cost on training data: 0.3510178755795136
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.992808536524482
# Accuracy on evaluation data: 8635 / 10000
#
# Epoch 157 training complete
# Cost on training data: 0.3483468050715658
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9912825017799406
# Accuracy on evaluation data: 8651 / 10000
#
# Epoch 158 training complete
# Cost on training data: 0.3458090752853537
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9887910888779151
# Accuracy on evaluation data: 8649 / 10000
#
# Epoch 159 training complete
# Cost on training data: 0.3433264580727326
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9843449695612344
# Accuracy on evaluation data: 8652 / 10000
#
# Epoch 160 training complete
# Cost on training data: 0.34088029971968803
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9887824173846623
# Accuracy on evaluation data: 8648 / 10000
#
# Epoch 161 training complete
# Cost on training data: 0.338384280387731
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9824028855163555
# Accuracy on evaluation data: 8658 / 10000
#
# Epoch 162 training complete
# Cost on training data: 0.33607841907443425
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9816604328738695
# Accuracy on evaluation data: 8651 / 10000
#
# Epoch 163 training complete
# Cost on training data: 0.3336053743085881
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9774471920984042
# Accuracy on evaluation data: 8651 / 10000
#
# Epoch 164 training complete
# Cost on training data: 0.33121052802467427
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9834678638671266
# Accuracy on evaluation data: 8648 / 10000
#
# Epoch 165 training complete
# Cost on training data: 0.3293680303582061
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9816238949028188
# Accuracy on evaluation data: 8646 / 10000
#
# Epoch 166 training complete
# Cost on training data: 0.3267555735781751
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9797071897229394
# Accuracy on evaluation data: 8652 / 10000
#
# Epoch 167 training complete
# Cost on training data: 0.3243137551019808
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9700291391975795
# Accuracy on evaluation data: 8679 / 10000
#
# Epoch 168 training complete
# Cost on training data: 0.3220373312870127
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9749394377487831
# Accuracy on evaluation data: 8656 / 10000
#
# Epoch 169 training complete
# Cost on training data: 0.31961978373946215
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9711411019048072
# Accuracy on evaluation data: 8658 / 10000
#
# Epoch 170 training complete
# Cost on training data: 0.3173555383785304
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9665836478554742
# Accuracy on evaluation data: 8682 / 10000
#
# Epoch 171 training complete
# Cost on training data: 0.3153457988022394
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9617099371784477
# Accuracy on evaluation data: 8675 / 10000
#
# Epoch 172 training complete
# Cost on training data: 0.3130167336237523
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9702244809910212
# Accuracy on evaluation data: 8671 / 10000
#
# Epoch 173 training complete
# Cost on training data: 0.3107508646454172
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9611587490950748
# Accuracy on evaluation data: 8675 / 10000
#
# Epoch 174 training complete
# Cost on training data: 0.30854665126382025
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9617325077109821
# Accuracy on evaluation data: 8673 / 10000
#
# Epoch 175 training complete
# Cost on training data: 0.30650052551915846
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9610263792481781
# Accuracy on evaluation data: 8672 / 10000
#
# Epoch 176 training complete
# Cost on training data: 0.3044459475226953
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9623167304748502
# Accuracy on evaluation data: 8673 / 10000
#
# Epoch 177 training complete
# Cost on training data: 0.3022389536618783
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9581600978203726
# Accuracy on evaluation data: 8671 / 10000
#
# Epoch 178 training complete
# Cost on training data: 0.3003274176816441
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9551193115998291
# Accuracy on evaluation data: 8667 / 10000
#
# Epoch 179 training complete
# Cost on training data: 0.2981249657134449
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9542276984903691
# Accuracy on evaluation data: 8682 / 10000
#
# Epoch 180 training complete
# Cost on training data: 0.2962928946771994
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9503220614200232
# Accuracy on evaluation data: 8682 / 10000
#
# Epoch 181 training complete
# Cost on training data: 0.29416764045183247
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9552463391796757
# Accuracy on evaluation data: 8672 / 10000
#
# Epoch 182 training complete
# Cost on training data: 0.2922106392817002
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9505540274284586
# Accuracy on evaluation data: 8687 / 10000
#
# Epoch 183 training complete
# Cost on training data: 0.29017375687412617
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9489535987468544
# Accuracy on evaluation data: 8680 / 10000
#
# Epoch 184 training complete
# Cost on training data: 0.28816760773281425
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9476266212655053
# Accuracy on evaluation data: 8694 / 10000
#
# Epoch 185 training complete
# Cost on training data: 0.2863701542838705
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9435191517029973
# Accuracy on evaluation data: 8672 / 10000
#
# Epoch 186 training complete
# Cost on training data: 0.2844631764154207
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9404053827824413
# Accuracy on evaluation data: 8690 / 10000
#
# Epoch 187 training complete
# Cost on training data: 0.282544345437801
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9412527755903294
# Accuracy on evaluation data: 8702 / 10000
#
# Epoch 188 training complete
# Cost on training data: 0.2806559525279946
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9417873566290871
# Accuracy on evaluation data: 8691 / 10000
#
# Epoch 189 training complete
# Cost on training data: 0.2787938045417791
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9413107849037573
# Accuracy on evaluation data: 8691 / 10000
#
# Epoch 190 training complete
# Cost on training data: 0.2769949511990688
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9401463208942962
# Accuracy on evaluation data: 8696 / 10000
#
# Epoch 191 training complete
# Cost on training data: 0.2754030683811117
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.943868219711177
# Accuracy on evaluation data: 8677 / 10000
#
# Epoch 192 training complete
# Cost on training data: 0.2734739517353004
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9381047931221403
# Accuracy on evaluation data: 8682 / 10000
#
# Epoch 193 training complete
# Cost on training data: 0.2718292823011516
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9314685862992778
# Accuracy on evaluation data: 8697 / 10000
#
# Epoch 194 training complete
# Cost on training data: 0.2699333167642288
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9345800804063517
# Accuracy on evaluation data: 8697 / 10000
#
# Epoch 195 training complete
# Cost on training data: 0.26823430825957784
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9331726019354766
# Accuracy on evaluation data: 8696 / 10000
#
# Epoch 196 training complete
# Cost on training data: 0.26652572282327597
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9347713009235149
# Accuracy on evaluation data: 8691 / 10000
#
# Epoch 197 training complete
# Cost on training data: 0.2646690663259249
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9291186754980819
# Accuracy on evaluation data: 8702 / 10000
#
# Epoch 198 training complete
# Cost on training data: 0.26315818237128746
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9333914214218741
# Accuracy on evaluation data: 8696 / 10000
#
# Epoch 199 training complete
# Cost on training data: 0.26142929208332777
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9255386364366693
# Accuracy on evaluation data: 8698 / 10000
#
# Epoch 200 training complete
# Cost on training data: 0.2598843295549603
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9254574612566548
# Accuracy on evaluation data: 8698 / 10000
#
# Epoch 201 training complete
# Cost on training data: 0.2582325866053983
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9183156180736414
# Accuracy on evaluation data: 8708 / 10000
#
# Epoch 202 training complete
# Cost on training data: 0.25651692725599984
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9184704266404059
# Accuracy on evaluation data: 8699 / 10000
#
# Epoch 203 training complete
# Cost on training data: 0.255035975068379
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9216922315408512
# Accuracy on evaluation data: 8712 / 10000
#
# Epoch 204 training complete
# Cost on training data: 0.25328351774511704
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9175982677895075
# Accuracy on evaluation data: 8710 / 10000
#
# Epoch 205 training complete
# Cost on training data: 0.2519761279415041
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9181208176681313
# Accuracy on evaluation data: 8707 / 10000
#
# Epoch 206 training complete
# Cost on training data: 0.25030667930606015
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9211994710820723
# Accuracy on evaluation data: 8699 / 10000
#
# Epoch 207 training complete
# Cost on training data: 0.24872531465576597
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9132826696605506
# Accuracy on evaluation data: 8717 / 10000
#
# Epoch 208 training complete
# Cost on training data: 0.2471338806098661
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9177597474648415
# Accuracy on evaluation data: 8707 / 10000
#
# Epoch 209 training complete
# Cost on training data: 0.2456563916201038
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9189777271667146
# Accuracy on evaluation data: 8702 / 10000
#
# Epoch 210 training complete
# Cost on training data: 0.24413047078704356
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9132890861362364
# Accuracy on evaluation data: 8707 / 10000
#
# Epoch 211 training complete
# Cost on training data: 0.24265039013806058
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9131843365691537
# Accuracy on evaluation data: 8707 / 10000
#
# Epoch 212 training complete
# Cost on training data: 0.24150312895940335
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9085097591095929
# Accuracy on evaluation data: 8723 / 10000
#
# Epoch 213 training complete
# Cost on training data: 0.23978678937273276
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9106277206891839
# Accuracy on evaluation data: 8712 / 10000
#
# Epoch 214 training complete
# Cost on training data: 0.23855970507589036
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9051133412297692
# Accuracy on evaluation data: 8721 / 10000
#
# Epoch 215 training complete
# Cost on training data: 0.23697584795682936
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9083630421483322
# Accuracy on evaluation data: 8714 / 10000
#
# Epoch 216 training complete
# Cost on training data: 0.235624506354499
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9113692673854653
# Accuracy on evaluation data: 8698 / 10000
#
# Epoch 217 training complete
# Cost on training data: 0.2341330013470204
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9001722147030371
# Accuracy on evaluation data: 8726 / 10000
#
# Epoch 218 training complete
# Cost on training data: 0.2327895849645189
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9034166398891961
# Accuracy on evaluation data: 8724 / 10000
#
# Epoch 219 training complete
# Cost on training data: 0.23143178689804375
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9029021192150168
# Accuracy on evaluation data: 8725 / 10000
#
# Epoch 220 training complete
# Cost on training data: 0.2300804971578101
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9031630947756497
# Accuracy on evaluation data: 8724 / 10000
#
# Epoch 221 training complete
# Cost on training data: 0.2287277033775543
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9016470801540067
# Accuracy on evaluation data: 8730 / 10000
#
# Epoch 222 training complete
# Cost on training data: 0.2274026793690938
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8995335569345849
# Accuracy on evaluation data: 8735 / 10000
#
# Epoch 223 training complete
# Cost on training data: 0.22641170830339044
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.9062131865928967
# Accuracy on evaluation data: 8709 / 10000
#
# Epoch 224 training complete
# Cost on training data: 0.22480693614662697
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8993946454117032
# Accuracy on evaluation data: 8728 / 10000
#
# Epoch 225 training complete
# Cost on training data: 0.2235853258669467
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8949757368995557
# Accuracy on evaluation data: 8729 / 10000
#
# Epoch 226 training complete
# Cost on training data: 0.22253338494915945
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.895966786844453
# Accuracy on evaluation data: 8730 / 10000
#
# Epoch 227 training complete
# Cost on training data: 0.22110598100820963
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8966603499747005
# Accuracy on evaluation data: 8732 / 10000
#
# Epoch 228 training complete
# Cost on training data: 0.21981016431295675
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8941361832156762
# Accuracy on evaluation data: 8735 / 10000
#
# Epoch 229 training complete
# Cost on training data: 0.2186891835154068
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8934725455928165
# Accuracy on evaluation data: 8726 / 10000
#
# Epoch 230 training complete
# Cost on training data: 0.21754324641319886
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8977902995676593
# Accuracy on evaluation data: 8723 / 10000
#
# Epoch 231 training complete
# Cost on training data: 0.21626733527422115
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8914781004428246
# Accuracy on evaluation data: 8737 / 10000
#
# Epoch 232 training complete
# Cost on training data: 0.2150087016741424
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8914044252218657
# Accuracy on evaluation data: 8737 / 10000
#
# Epoch 233 training complete
# Cost on training data: 0.21401221850352647
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8888695682678476
# Accuracy on evaluation data: 8739 / 10000
#
# Epoch 234 training complete
# Cost on training data: 0.2126674942009632
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8886812049170137
# Accuracy on evaluation data: 8730 / 10000
#
# Epoch 235 training complete
# Cost on training data: 0.21149211580322588
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8879308722897807
# Accuracy on evaluation data: 8741 / 10000
#
# Epoch 236 training complete
# Cost on training data: 0.2104057888678409
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8915794552192954
# Accuracy on evaluation data: 8731 / 10000
#
# Epoch 237 training complete
# Cost on training data: 0.2092457106899696
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8871663301950365
# Accuracy on evaluation data: 8731 / 10000
#
# Epoch 238 training complete
# Cost on training data: 0.20809821135693368
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8883069325144156
# Accuracy on evaluation data: 8735 / 10000
#
# Epoch 239 training complete
# Cost on training data: 0.20706659939096866
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8812544030857052
# Accuracy on evaluation data: 8743 / 10000
#
# Epoch 240 training complete
# Cost on training data: 0.20591076253789467
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.876641784459314
# Accuracy on evaluation data: 8743 / 10000
#
# Epoch 241 training complete
# Cost on training data: 0.20489735345188853
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8808194202026143
# Accuracy on evaluation data: 8738 / 10000
#
# Epoch 242 training complete
# Cost on training data: 0.20377045922709652
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8832710908438495
# Accuracy on evaluation data: 8753 / 10000
#
# Epoch 243 training complete
# Cost on training data: 0.20290301054394996
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8849454940362232
# Accuracy on evaluation data: 8723 / 10000
#
# Epoch 244 training complete
# Cost on training data: 0.20155319555877177
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8807766285375178
# Accuracy on evaluation data: 8732 / 10000
#
# Epoch 245 training complete
# Cost on training data: 0.20087845232732937
# Accuracy on training data: 1000 / 1000
# ...
# Accuracy on evaluation data: 8806 / 10000
#
# Epoch 319 training complete
# Cost on training data: 0.1451312357012023
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8321719207892974
# Accuracy on evaluation data: 8794 / 10000
#
# Epoch 320 training complete
# Cost on training data: 0.1446448600807469
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8396370203158714
# Accuracy on evaluation data: 8792 / 10000
#
# Epoch 321 training complete
# Cost on training data: 0.1441361315625913
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8413115739359702
# Accuracy on evaluation data: 8771 / 10000
#
# Epoch 322 training complete
# Cost on training data: 0.14352726183387338
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8347448272489078
# Accuracy on evaluation data: 8789 / 10000
#
# Epoch 323 training complete
# Cost on training data: 0.1429851658998029
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8371395196635238
# Accuracy on evaluation data: 8795 / 10000
#
# Epoch 324 training complete
# Cost on training data: 0.1427538186010752
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8292602209987754
# Accuracy on evaluation data: 8808 / 10000
#
# Epoch 325 training complete
# Cost on training data: 0.1420964649580058
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8309560377554072
# Accuracy on evaluation data: 8787 / 10000
#
# Epoch 326 training complete
# Cost on training data: 0.1415320806126231
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8303840313408923
# Accuracy on evaluation data: 8805 / 10000
#
# Epoch 327 training complete
# Cost on training data: 0.14101986127328028
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8303968444116292
# Accuracy on evaluation data: 8802 / 10000
#
# Epoch 328 training complete
# Cost on training data: 0.14062521791716973
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8339895725765453
# Accuracy on evaluation data: 8792 / 10000
#
# Epoch 329 training complete
# Cost on training data: 0.1401873764727677
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8289179716221414
# Accuracy on evaluation data: 8797 / 10000
#
# Epoch 330 training complete
# Cost on training data: 0.1397209338572843
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8312979496551852
# Accuracy on evaluation data: 8803 / 10000
#
# Epoch 331 training complete
# Cost on training data: 0.13916359098483255
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8324032220164581
# Accuracy on evaluation data: 8803 / 10000
#
# Epoch 332 training complete
# Cost on training data: 0.1386155090372961
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8251982811302286
# Accuracy on evaluation data: 8809 / 10000
#
# Epoch 333 training complete
# Cost on training data: 0.1381844404270363
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8257221345478105
# Accuracy on evaluation data: 8812 / 10000
#
# Epoch 334 training complete
# Cost on training data: 0.13785762284903888
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.827970677502875
# Accuracy on evaluation data: 8813 / 10000
#
# Epoch 335 training complete
# Cost on training data: 0.1373433504478211
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8252465320545798
# Accuracy on evaluation data: 8818 / 10000
#
# Epoch 336 training complete
# Cost on training data: 0.13687527236004104
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8229261731664059
# Accuracy on evaluation data: 8812 / 10000
#
# Epoch 337 training complete
# Cost on training data: 0.13639647165092383
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8254536636458585
# Accuracy on evaluation data: 8811 / 10000
#
# Epoch 338 training complete
# Cost on training data: 0.13605785807306256
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.829049851875509
# Accuracy on evaluation data: 8798 / 10000
#
# Epoch 339 training complete
# Cost on training data: 0.13562399254250218
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8249159234347087
# Accuracy on evaluation data: 8810 / 10000
#
# Epoch 340 training complete
# Cost on training data: 0.13530778431167764
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8291990759165344
# Accuracy on evaluation data: 8798 / 10000
#
# Epoch 341 training complete
# Cost on training data: 0.13472875722510386
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.824796902961573
# Accuracy on evaluation data: 8809 / 10000
#
# Epoch 342 training complete
# Cost on training data: 0.13435763945094006
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8234130335153755
# Accuracy on evaluation data: 8811 / 10000
#
# Epoch 343 training complete
# Cost on training data: 0.13414130720987158
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8311926846479565
# Accuracy on evaluation data: 8780 / 10000
#
# Epoch 344 training complete
# Cost on training data: 0.13347042833981887
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8253381357204589
# Accuracy on evaluation data: 8812 / 10000
#
# Epoch 345 training complete
# Cost on training data: 0.13325401718185587
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8225175544933084
# Accuracy on evaluation data: 8806 / 10000
#
# Epoch 346 training complete
# Cost on training data: 0.13277636518723562
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8195003521942406
# Accuracy on evaluation data: 8815 / 10000
#
# Epoch 347 training complete
# Cost on training data: 0.13242346460569096
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8288671048485743
# Accuracy on evaluation data: 8805 / 10000
#
# Epoch 348 training complete
# Cost on training data: 0.1319244939101221
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8285846121749804
# Accuracy on evaluation data: 8808 / 10000
#
# Epoch 349 training complete
# Cost on training data: 0.13160455683437491
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8201873001946207
# Accuracy on evaluation data: 8819 / 10000
#
# Epoch 350 training complete
# Cost on training data: 0.13110096238998967
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.822408900413881
# Accuracy on evaluation data: 8801 / 10000
#
# Epoch 351 training complete
# Cost on training data: 0.1308693011858697
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8190041486414991
# Accuracy on evaluation data: 8824 / 10000
#
# Epoch 352 training complete
# Cost on training data: 0.1303931944975064
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8166902355892683
# Accuracy on evaluation data: 8820 / 10000
#
# Epoch 353 training complete
# Cost on training data: 0.13002739273693129
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8234013183860229
# Accuracy on evaluation data: 8806 / 10000
#
# Epoch 354 training complete
# Cost on training data: 0.12970035640134597
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8263114120715384
# Accuracy on evaluation data: 8796 / 10000
#
# Epoch 355 training complete
# Cost on training data: 0.12955624056481524
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8203346070337687
# Accuracy on evaluation data: 8808 / 10000
#
# Epoch 356 training complete
# Cost on training data: 0.12890507941487434
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.82095650891388
# Accuracy on evaluation data: 8809 / 10000
#
# Epoch 357 training complete
# Cost on training data: 0.1285824636461383
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8168230068231597
# Accuracy on evaluation data: 8825 / 10000
#
# Epoch 358 training complete
# Cost on training data: 0.12821397789607342
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8143050330124532
# Accuracy on evaluation data: 8829 / 10000
#
# Epoch 359 training complete
# Cost on training data: 0.1279246902335071
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8192678760578663
# Accuracy on evaluation data: 8817 / 10000
#
# Epoch 360 training complete
# Cost on training data: 0.12747038845484748
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.818638624984218
# Accuracy on evaluation data: 8825 / 10000
#
# Epoch 361 training complete
# Cost on training data: 0.12707809961402747
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8186379646179527
# Accuracy on evaluation data: 8824 / 10000
#
# Epoch 362 training complete
# Cost on training data: 0.12672619920834996
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8195822067712812
# Accuracy on evaluation data: 8816 / 10000
#
# Epoch 363 training complete
# Cost on training data: 0.12641248018015394
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8151160780286492
# Accuracy on evaluation data: 8813 / 10000
#
# Epoch 364 training complete
# Cost on training data: 0.12612874167870566
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8216089415666082
# Accuracy on evaluation data: 8814 / 10000
#
# Epoch 365 training complete
# Cost on training data: 0.12582979419799536
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8239221299727854
# Accuracy on evaluation data: 8796 / 10000
#
# Epoch 366 training complete
# Cost on training data: 0.12542549978044507
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8176886226956599
# Accuracy on evaluation data: 8812 / 10000
#
# Epoch 367 training complete
# Cost on training data: 0.12524868708611087
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8243873688403216
# Accuracy on evaluation data: 8803 / 10000
#
# Epoch 368 training complete
# Cost on training data: 0.12482835126236176
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.817583472482348
# Accuracy on evaluation data: 8826 / 10000
#
# Epoch 369 training complete
# Cost on training data: 0.1244221126950262
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.817663647134042
# Accuracy on evaluation data: 8815 / 10000
#
# Epoch 370 training complete
# Cost on training data: 0.12419295285185476
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8128583240793305
# Accuracy on evaluation data: 8828 / 10000
#
# Epoch 371 training complete
# Cost on training data: 0.12385665938999306
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8175566550855511
# Accuracy on evaluation data: 8812 / 10000
#
# Epoch 372 training complete
# Cost on training data: 0.12364305251445903
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.818575255556578
# Accuracy on evaluation data: 8807 / 10000
#
# Epoch 373 training complete
# Cost on training data: 0.12324547797251714
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8094822297177794
# Accuracy on evaluation data: 8824 / 10000
#
# Epoch 374 training complete
# Cost on training data: 0.12332732832123564
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8233349400105525
# Accuracy on evaluation data: 8794 / 10000
#
# Epoch 375 training complete
# Cost on training data: 0.12266425946372492
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8119341297935263
# Accuracy on evaluation data: 8823 / 10000
#
# Epoch 376 training complete
# Cost on training data: 0.12242275566968094
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.825748188996864
# Accuracy on evaluation data: 8799 / 10000
#
# Epoch 377 training complete
# Cost on training data: 0.12200101850432565
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8183869344421244
# Accuracy on evaluation data: 8811 / 10000
#
# Epoch 378 training complete
# Cost on training data: 0.12204511091557563
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.809314604825905
# Accuracy on evaluation data: 8827 / 10000
#
# Epoch 379 training complete
# Cost on training data: 0.12151206060608863
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8148837769260051
# Accuracy on evaluation data: 8819 / 10000
#
# Epoch 380 training complete
# Cost on training data: 0.12124654951410341
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8122970250806734
# Accuracy on evaluation data: 8826 / 10000
#
# Epoch 381 training complete
# Cost on training data: 0.12076334173074418
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8160021349661277
# Accuracy on evaluation data: 8820 / 10000
#
# Epoch 382 training complete
# Cost on training data: 0.12069988653693792
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8127871549741786
# Accuracy on evaluation data: 8830 / 10000
#
# Epoch 383 training complete
# Cost on training data: 0.1202792450191223
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8134265262230669
# Accuracy on evaluation data: 8823 / 10000
#
# Epoch 384 training complete
# Cost on training data: 0.11996075083836792
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8157463907244796
# Accuracy on evaluation data: 8820 / 10000
#
# Epoch 385 training complete
# Cost on training data: 0.11973747738136123
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.819563093863996
# Accuracy on evaluation data: 8801 / 10000
#
# Epoch 386 training complete
# Cost on training data: 0.11950783174377874
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8173440475139879
# Accuracy on evaluation data: 8801 / 10000
#
# Epoch 387 training complete
# Cost on training data: 0.11918314748593295
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.814333366865086
# Accuracy on evaluation data: 8836 / 10000
#
# Epoch 388 training complete
# Cost on training data: 0.11909888055304935
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8119657738017462
# Accuracy on evaluation data: 8829 / 10000
#
# Epoch 389 training complete
# Cost on training data: 0.11869805858981249
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8096466248760268
# Accuracy on evaluation data: 8821 / 10000
#
# Epoch 390 training complete
# Cost on training data: 0.11837418542154585
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8178575548060384
# Accuracy on evaluation data: 8816 / 10000
#
# Epoch 391 training complete
# Cost on training data: 0.11826460943013929
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8097526454287041
# Accuracy on evaluation data: 8822 / 10000
#
# Epoch 392 training complete
# Cost on training data: 0.11800542626650351
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8163619250420049
# Accuracy on evaluation data: 8819 / 10000
#
# Epoch 393 training complete
# Cost on training data: 0.11758922048734544
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8104819669093452
# Accuracy on evaluation data: 8823 / 10000
#
# Epoch 394 training complete
# Cost on training data: 0.11746917475161267
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.814232009361087
# Accuracy on evaluation data: 8810 / 10000
#
# Epoch 395 training complete
# Cost on training data: 0.11698614027121562
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8098357123221605
# Accuracy on evaluation data: 8824 / 10000
#
# Epoch 396 training complete
# Cost on training data: 0.11680953907134778
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8067241019318913
# Accuracy on evaluation data: 8827 / 10000
#
# Epoch 397 training complete
# Cost on training data: 0.11676145919191633
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8133143987091388
# Accuracy on evaluation data: 8821 / 10000
#
# Epoch 398 training complete
# Cost on training data: 0.1163802445811001
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8177539243531685
# Accuracy on evaluation data: 8811 / 10000
#
# Epoch 399 training complete
# Cost on training data: 0.1160466870525705
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8101663725675884
# Accuracy on evaluation data: 8832 / 10000

# %%
plt.plot(np.arange(200,400),training_cost[200:])
plt.xlabel("Epoch")
plt.ylabel("Cost")
plt.title("Cost on training data")
plt.show()
# Out:
# <div id='b7151131-f961-4593-bb9b-5adc75017e76'></div>

# %%
plt.plot(np.arange(200,400),evaluation_accuracy[200:])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy on test data")
plt.show()
# Out:
# <div id='d9802e18-30ff-481c-a070-bb8dcba3e22a'></div>

# %%
plt.plot(np.arange(400),evaluation_cost)
plt.xlabel("Epoch")
plt.title("Cost on test data")
plt.show()
# Out:
# <div id='9dba72c5-db6b-46d5-9594-ead527b6b7ac'></div>

# %%
plt.plot(np.arange(400),training_accuracy)
plt.xlabel("Epoch")
plt.title("Acuuracy on training data")
plt.show()
# Out:
# <div id='cbc78b42-f4c5-449e-b1ee-4d74277ca31d'></div>

# %%
training_data, validation_Data, test_data = load_data_wrapper()
net = Network([784, 30, 10], cost=CrossEntropyCost)
net.large_weight_initializer()
evaluation_cost, evaluation_accuracy, training_cost, training_accuracy = net.SGD(
    training_data,
    30, 10, 0.5,
    lmbda=5.0,
    evaluation_data=test_data,
    monitor_evaluation_accuracy=True,
    monitor_training_cost=False,
    monitor_evaluation_cost=False,
    monitor_training_accuracy=True)
# Out:
# Epoch 0 training complete
# Accuracy on training data: 45727 / 50000
# Accuracy on evaluation data: 9122 / 10000
#
# Epoch 1 training complete
# Accuracy on training data: 46789 / 50000
# Accuracy on evaluation data: 9327 / 10000
#
# Epoch 2 training complete
# Accuracy on training data: 47252 / 50000
# Accuracy on evaluation data: 9402 / 10000
#
# Epoch 3 training complete
# Accuracy on training data: 47596 / 50000
# Accuracy on evaluation data: 9454 / 10000
#
# Epoch 4 training complete
# Accuracy on training data: 47766 / 50000
# Accuracy on evaluation data: 9437 / 10000
#
# Epoch 5 training complete
# Accuracy on training data: 48017 / 50000
# Accuracy on evaluation data: 9506 / 10000
#
# Epoch 6 training complete
# Accuracy on training data: 48046 / 50000
# Accuracy on evaluation data: 9531 / 10000
#
# Epoch 7 training complete
# Accuracy on training data: 48157 / 50000
# Accuracy on evaluation data: 9535 / 10000
#
# Epoch 8 training complete
# Accuracy on training data: 48266 / 50000
# Accuracy on evaluation data: 9541 / 10000
#
# Epoch 9 training complete
# Accuracy on training data: 48183 / 50000
# Accuracy on evaluation data: 9529 / 10000
#
# Epoch 10 training complete
# Accuracy on training data: 48168 / 50000
# Accuracy on evaluation data: 9537 / 10000
#
# Epoch 11 training complete
# Accuracy on training data: 48406 / 50000
# Accuracy on evaluation data: 9589 / 10000
#
# Epoch 12 training complete
# Accuracy on training data: 48121 / 50000
# Accuracy on evaluation data: 9516 / 10000
#
# Epoch 13 training complete
# Accuracy on training data: 48412 / 50000
# Accuracy on evaluation data: 9601 / 10000
#
# Epoch 14 training complete
# Accuracy on training data: 48439 / 50000
# Accuracy on evaluation data: 9584 / 10000
#
# Epoch 15 training complete
# Accuracy on training data: 48499 / 50000
# Accuracy on evaluation data: 9608 / 10000
#
# Epoch 16 training complete
# Accuracy on training data: 48401 / 50000
# Accuracy on evaluation data: 9580 / 10000
#
# Epoch 17 training complete
# Accuracy on training data: 48485 / 50000
# Accuracy on evaluation data: 9589 / 10000
#
# Epoch 18 training complete
# Accuracy on training data: 48319 / 50000
# Accuracy on evaluation data: 9552 / 10000
#
# Epoch 19 training complete
# Accuracy on training data: 48435 / 50000
# Accuracy on evaluation data: 9590 / 10000
#
# Epoch 20 training complete
# Accuracy on training data: 48446 / 50000
# Accuracy on evaluation data: 9573 / 10000
#
# Epoch 21 training complete
# Accuracy on training data: 48543 / 50000
# Accuracy on evaluation data: 9588 / 10000
#
# Epoch 22 training complete
# Accuracy on training data: 48460 / 50000
# Accuracy on evaluation data: 9595 / 10000
#
# Epoch 23 training complete
# Accuracy on training data: 48222 / 50000
# Accuracy on evaluation data: 9533 / 10000
#
# Epoch 24 training complete
# Accuracy on training data: 48471 / 50000
# Accuracy on evaluation data: 9580 / 10000
#
# Epoch 25 training complete
# Accuracy on training data: 48320 / 50000
# Accuracy on evaluation data: 9592 / 10000
#
# Epoch 26 training complete
# Accuracy on training data: 48432 / 50000
# Accuracy on evaluation data: 9609 / 10000
#
# Epoch 27 training complete
# Accuracy on training data: 48192 / 50000
# Accuracy on evaluation data: 9562 / 10000
#
# Epoch 28 training complete
# Accuracy on training data: 48582 / 50000
# Accuracy on evaluation data: 9607 / 10000
#
# Epoch 29 training complete
# Accuracy on training data: 48178 / 50000
# Accuracy on evaluation data: 9526 / 10000

# %%
plt.plot(np.arange(30),np.array(training_accuracy)/50000,label="Training Accuracy")
plt.plot(np.arange(30),np.array(evaluation_accuracy)/10000,label="Test Accuracy")
plt.legend()
plt.show()
# Out:
# <div id='7e33da06-81ef-49b9-8eae-6c757bd9894f'></div>

# %%
n
