# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.inspection import DecisionBoundaryDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/1.ushape.csv",names=["x1","x2","y"])
data.head()
# Out:
#          x1        x2    y
# 0  0.031595  0.986988  0.0
# 1  2.115098 -0.046244  1.0
# 2  0.882490 -0.075756  0.0
# 3 -0.055144 -0.037332  1.0
# 4  0.829545 -0.539321  1.0

# %%
def compare(data):
    neig =  [1, 5, 15, 30, 40,45]
    fig,axes = plt.subplots(nrows=3,ncols=2,figsize=(8,12))
    for ax,k in zip(axes.ravel(),neig):
        X = data.drop("y",axis=1).values
        y = data["y"].values
        clf = KNeighborsClassifier(n_neighbors=k)
        clf.fit(X,y)
        DecisionBoundaryDisplay.from_estimator(clf,X,response_method="predict",ax=ax,alpha=0.2)
        sns.scatterplot(x=X[:,0],y=X[:,1],hue=y,ax=ax)
        ax.set_title(f"k = {k}")

# %%
compare(data)

# %%
from os import walk
filenames = list(walk("data"))[0][2]

# %%
filenames
# Out:
# ['1.ushape.csv',
#  '2.concerticcir1.csv',
#  '3.concertriccir2.csv',
#  '4.linearsep.csv',
#  '5.outlier.csv',
#  '6.overlap.csv',
#  '7.xor.csv',
#  '8.twospirals.csv',
#  '9.random.csv']

# %%
for ex in filenames:
    data = pd.read_csv(f"data/{ex}",names=["x1","x2","y"])
    print("="*75)
    print(ex)
    print("="*75)
    compare(data)
    plt.show()
# Out:
# ...
# 1.ushape.csv
# ...
# 2.concerticcir1.csv
# ...
# 3.concertriccir2.csv
# ...
# 4.linearsep.csv
# ...
# 5.outlier.csv
# ...
# 6.overlap.csv
# ...
# 7.xor.csv
# ...
# 8.twospirals.csv
# ...
# 9.random.csv
# ...
